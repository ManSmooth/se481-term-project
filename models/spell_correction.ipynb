# %%
import pandas as pd
from multiprocessing import cpu_count, Pool
import itertools
from string import ascii_lowercase
import os
import re
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer

# %%
norvig = pd.read_csv(
    "http://norvig.com/ngrams/count_1edit.txt",
    sep="\t",
    encoding="ISO-8859-1",
    header=None,
)
norvig.columns = ["term", "edit"]
norvig = norvig.set_index("term")
norvig
# Out:
#        edit
# term
# e|i     917
# a|e     856
# i|e     771
# e|a     749
# a|i     559
# ...     ...
#  |c       1
#  |a       1
#  |'       1
#  w|       1
#  t|t      1
#
# [1587 rows x 1 columns]

# %%
norvig_orig = pd.read_csv(
    "http://norvig.com/ngrams/count_big.txt",
    sep="\t",
    encoding="ISO-8859-1",
    header=None,
)
norvig_orig.dropna(inplace=True)
norvig_orig.columns = ["term", "freq"]
norvig_orig
# Out:
#             term   freq
# 0              a  21160
# 1            aah      1
# 2          aaron      5
# 3             ab      2
# 4          aback      3
# ...          ...    ...
# 29131    zueblin      1
# 29132        zum      1
# 29133      zweck      1
# 29134     zygoma      1
# 29135  zygomatic      1
#
# [29134 rows x 2 columns]

# %%
def get_count(c, norvig_orig):
    return norvig_orig.apply(lambda x: x["term"].count(c) * x["freq"], axis=1).sum()


character_set = list(map("".join, itertools.product(ascii_lowercase, repeat=1))) + list(
    map("".join, itertools.product(ascii_lowercase, repeat=2))
)

freq_list = []
with Pool(cpu_count()) as p:
    freq_list = p.starmap(get_count, zip(character_set, itertools.repeat(norvig_orig)))

freq_df = pd.DataFrame([character_set, freq_list], index=['char', 'freq']).T
freq_df = freq_df.set_index('char')
freq_df
# Out:
#         freq
# char
# a     407349
# b      73161
# c     144964
# d     215698
# e     632999
# ...      ...
# zv         1
# zw         1
# zx         0
# zy        32
# zz        83
#
# [702 rows x 1 columns]

# %%
recipes_df = pd.read_parquet("~/resources/food/recipes.parquet")
texts_df = recipes_df[["Name", "Description"]].join(recipes_df["RecipeInstructions"].transform(" ".join).to_frame("RecipeInstructions")).fillna("").agg(" ".join, axis=1)
texts_df.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 522517 entries, 0 to 522516
# Series name: None
# Non-Null Count   Dtype
# --------------   -----
# 522517 non-null  object
# dtypes: object(1)
# memory usage: 4.0+ MB

# %%
texts_df
# Out:
# 0         Low-Fat Berry Blue Frozen Dessert Make and sha...
# 1         Biryani Make and share this Biryani recipe fro...
# 2         Best Lemonade This is from one of my  first Go...
# 3         Carina's Tofu-Vegetable Kebabs This dish is be...
# 4         Cabbage Soup Make and share this Cabbage Soup ...
#                                 ...
# 522512    Meg's Fresh Ginger Gingerbread Make and share ...
# 522513    Roast Prime Rib au Poivre with Mixed Peppercor...
# 522514    Kirshwasser Ice Cream Make and share this Kirs...
# 522515    Quick & Easy Asian Cucumber Salmon Rolls Extre...
# 522516    Spicy Baked Scotch Eggs Great way to have hard...
# Length: 522517, dtype: object

# %%
def process(s: str):
    s = re.sub(r"[^A-Za-z]", " ", s)
    s = re.sub(r"[\d]", " ", s)
    s = re.sub(r"\s+", " ", s)
    s = s.lower()
    return s.strip()

texts_df = texts_df.apply(process)
texts_df
# Out:
# 0         low fat berry blue frozen dessert make and sha...
# 1         biryani make and share this biryani recipe fro...
# 2         best lemonade this is from one of my first goo...
# 3         carina s tofu vegetable kebabs this dish is be...
# 4         cabbage soup make and share this cabbage soup ...
#                                 ...
# 522512    meg s fresh ginger gingerbread make and share ...
# 522513    roast prime rib au poivre with mixed peppercor...
# 522514    kirshwasser ice cream make and share this kirs...
# 522515    quick easy asian cucumber salmon rolls extreme...
# 522516    spicy baked scotch eggs great way to have hard...
# Length: 522517, dtype: object

# %%
from nltk.tokenize import word_tokenize

iula_count_vectorizer = CountVectorizer(preprocessor=process, tokenizer=word_tokenize, stop_words='english', ngram_range=(1, 2))
freq_iula = iula_count_vectorizer.fit_transform(texts_df)
freq_iula
# Out:
# <522517x4384022 sparse matrix of type '<class 'numpy.int64'>'
# 	with 70525700 stored elements in Compressed Sparse Row format>

# %%
freq_iula_sum = pd.Series(
    np.squeeze(np.asarray(freq_iula.sum(axis=0))),
    index=iula_count_vectorizer.get_feature_names_out(),
)
iula_total = freq_iula.sum()
print(f"{iula_total=}")

iula_freq_len_mapping = freq_iula_sum.groupby(lambda x: len(x)).apply(lambda x: set(x.index.to_list()))
freq_iula_sum
# Out:
# iula_total=83383309
# aa                                  30
# aa aarmy                             1
# aa b                                 1
# aa bc                                1
# aa c                                 1
#                                     ..
# zzzzzzzzzzzzz epsom                  1
# zzzzzzzzzzzzzssssssssssssss          1
# zzzzzzzzzzzzzssssssssssssss hear     1
# zzzzzzzzzzzzzzzz                     1
# zzzzzzzzzzzzzzzz did                 1
# Length: 4384022, dtype: int64

# %%
freq_iula_sum.sort_values(ascending=False)
# Out:
# and                   3384649
# the                   3183145
# to                    1723182
# in                    1610827
# with                  1150063
#                        ...
# ingredients heard           1
# ingredients heart           1
# ingredients hearty          1
# ingredients hello           1
# ﬂuffy like                  1
# Length: 3486587, dtype: int64

# %%
def edits1_with_correction(word):
    "All edits that are one edit away from `word`."
    letters = "abcdefghijklmnopqrstuvwxyz"
    splits = [(word[:i], word[i:]) for i in range(len(word) + 1)]
    deletes = [(L + R[1:], f"{R[0]}| ") for L, R in splits if R]
    transposes = [
        (L + R[1] + R[0] + R[2:], f"{R[0]+R[1]}|{R[1]+R[0]}")
        for L, R in splits
        if len(R) > 1
    ]
    replaces = [(L + c + R[1:], f"{R[0]}|{c}") for L, R in splits if R for c in letters]
    inserts = [(L + c + R, f" |{c}") for L, R in splits for c in letters]
    return set(deletes + transposes + replaces + inserts)


def get_candidates(word, len_mapping):
    # Get known words
    return {
        candidate
        for candidate in edits1_with_correction(word)
        if (
            len(candidate[0]) > 1 and candidate[0] in len_mapping[len(candidate[0])] and candidate[0] != word
        )
    }


def try_get(df: pd.DataFrame, key, default):
    return df.loc[key].values[0] if key in df.index else default

def calc_xw(x: str):
    target = x.split("|")
    if target[1] == " ":
        target = target[0]
    else:
        target = target[1]
    return try_get(norvig, x, 0) / try_get(freq_df, target, 1)


def get_corrections(word):
    terms_candidates = [get_candidates(term, iula_freq_len_mapping) for term in word.split()]
    query = [candidate[0] for candidate in terms_candidates]

    transformed_query = [
        iula_count_vectorizer.inverse_transform(iula_count_vectorizer.transform([q]))
        for q in query
    ]
    query_freq = pd.Series(
        [
            freq_iula_sum.T.loc[tq[0]].values[0] if len(tq[0]) > 0 else 0
            for tq in transformed_query
        ],
        index=query,
    )

    IULA = pd.DataFrame(query_freq, columns=["frequency"])
    IULA = IULA.join(
        pd.DataFrame(
            pd.Series([candidate[1] for candidate in candidates], index=query),
            columns=["correction"],
        )
    )
    IULA_pop = iula_total
    IULA["P(w)"] = IULA["frequency"] / IULA_pop
    IULA["P(x|w)"] = IULA["correction"].apply(lambda x: calc_xw(x))
    IULA["10^9 P(x|w)P(w)"] = 1e9 * IULA["P(w)"] * IULA["P(x|w)"]
    return IULA.sort_values("10^9 P(x|w)P(w)", ascending=False)

# %%
get_corrections("bef wellingon")
# Out:
#                 frequency correction      P(w)    P(x|w)  10^9 P(x|w)P(w)
# beef wellingon      74536         |e  0.000894  0.000009         8.472961

# %%
word = "boiled beef wellingon"
query = [[candidate[0] for candidate in get_candidates(term, iula_freq_len_mapping)] for term in word.split()]
corrections = [{candidate[0]: candidate[1] for candidate in get_candidates(term, iula_freq_len_mapping)} for term in word.split()]
corrections={k:v for d in corrections for k,v in d.items()}
combinations = np.array(np.meshgrid(*query)).T.reshape(-1,len(word.split()))
joined_combis = [" ".join(combi) for combi in combinations]
transformed_query = iula_count_vectorizer.inverse_transform(iula_count_vectorizer.transform(joined_combis))
transformed_query = [[query_term for query_term in [*query] if len(query_term.split()) == 1] for query in transformed_query]
scores = dict()
for i, terms in enumerate(transformed_query):
    term_freq = pd.Series([freq_iula_sum.get(term) for term in terms], index=terms)
    print(term_freq)
    IULA = IULA.join(
        pd.DataFrame(
            pd.Series([candidate[1] for candidate in candidates], index=query),
            columns=["correction"],
        )
    )
    bigrams = [term for term in terms if len(term.split()) > 1]
    scores[" ".join(transformed_query[i])] = np.prod([term_freq.loc[bigram]/term_freq.loc[bigram.split()[0]] for bigram in bigrams])
out = pd.DataFrame.from_dict(scores, orient='index', columns=["score"])
out.sort_values("score", ascending=False)
# Out:
# boiler        5457
# eef              1
# wellington     233
# dtype: int64
# boiler        5457
# deef             1
# wellington     233
# dtype: int64
# boiler        5457
# reef            19
# wellington     233
# dtype: int64
# bef              3
# boiler        5457
# wellington     233
# dtype: int64
# beefy          541
# boiler        5457
# wellington     233
# dtype: int64
# beek             1
# boiler        5457
# wellington     233
# dtype: int64
# beel             2
# boiler        5457
# wellington     233
# dtype: int64
# bee            241
# boiler        5457
# wellington     233
# dtype: int64
# beefs           12
# boiler        5457
# wellington     233
# dtype: int64
# bees            57
# boiler        5457
# wellington     233
# dtype: int64
# beaf             5
# boiler        5457
# wellington     233
# dtype: int64
# beet          1827
# boiler        5457
# wellington     233
# dtype: int64
# beez             2
# boiler        5457
# wellington     233
# dtype: int64
# beefl            1
# boiler        5457
# wellington     233
# dtype: int64
# beep           150
# boiler        5457
# wellington     233
# dtype: int64
# boiler        5457
# peef             1
# wellington     233
# dtype: int64
# beed            18
# boiler        5457
# wellington     233
# dtype: int64
# boiler        5457
# geef             1
# wellington     233
# dtype: int64
# beeef            4
# boiler        5457
# wellington     233
# dtype: int64
# beeff            1
# boiler        5457
# wellington     233
# dtype: int64
# beer          9159
# boiler        5457
# wellington     233
# dtype: int64
# beeg             1
# boiler        5457
# wellington     233
# dtype: int64
# boef             1
# boiler        5457
# wellington     233
# dtype: int64
# beff             3
# boiler        5457
# wellington     233
# dtype: int64
# boiler        5457
# teef             1
# wellington     233
# dtype: int64
# broiled       1691
# eef              1
# wellington     233
# dtype: int64
# broiled       1691
# deef             1
# wellington     233
# dtype: int64
# broiled       1691
# reef            19
# wellington     233
# dtype: int64
# bef              3
# broiled       1691
# wellington     233
# dtype: int64
# beefy          541
# broiled       1691
# wellington     233
# dtype: int64
# beek             1
# broiled       1691
# wellington     233
# dtype: int64
# beel             2
# broiled       1691
# wellington     233
# dtype: int64
# bee            241
# broiled       1691
# wellington     233
# dtype: int64
# beefs           12
# broiled       1691
# wellington     233
# dtype: int64
# bees            57
# broiled       1691
# wellington     233
# dtype: int64
# beaf             5
# broiled       1691
# wellington     233
# dtype: int64
# beet          1827
# broiled       1691
# wellington     233
# dtype: int64
# beez             2
# broiled       1691
# wellington     233
# dtype: int64
# beefl            1
# broiled       1691
# wellington     233
# dtype: int64
# beep           150
# broiled       1691
# wellington     233
# dtype: int64
# broiled       1691
# peef             1
# wellington     233
# dtype: int64
# beed            18
# broiled       1691
# wellington     233
# dtype: int64
# broiled       1691
# geef             1
# wellington     233
# dtype: int64
# beeef            4
# broiled       1691
# wellington     233
# dtype: int64
# beeff            1
# broiled       1691
# wellington     233
# dtype: int64
# beer          9159
# broiled       1691
# wellington     233
# dtype: int64
# beeg             1
# broiled       1691
# wellington     233
# dtype: int64
# boef             1
# broiled       1691
# wellington     233
# dtype: int64
# beff             3
# broiled       1691
# wellington     233
# dtype: int64
# broiled       1691
# teef             1
# wellington     233
# dtype: int64
# eef             1
# loiled          1
# wellington    233
# dtype: int64
# deef            1
# loiled          1
# wellington    233
# dtype: int64
# loiled          1
# reef           19
# wellington    233
# dtype: int64
# bef             3
# loiled          1
# wellington    233
# dtype: int64
# beefy         541
# loiled          1
# wellington    233
# dtype: int64
# beek            1
# loiled          1
# wellington    233
# dtype: int64
# beel            2
# loiled          1
# wellington    233
# dtype: int64
# bee           241
# loiled          1
# wellington    233
# dtype: int64
# beefs          12
# loiled          1
# wellington    233
# dtype: int64
# bees           57
# loiled          1
# wellington    233
# dtype: int64
# beaf            5
# loiled          1
# wellington    233
# dtype: int64
# beet          1827
# loiled           1
# wellington     233
# dtype: int64
# beez            2
# loiled          1
# wellington    233
# dtype: int64
# beefl           1
# loiled          1
# wellington    233
# dtype: int64
# beep          150
# loiled          1
# wellington    233
# dtype: int64
# loiled          1
# peef            1
# wellington    233
# dtype: int64
# beed           18
# loiled          1
# wellington    233
# dtype: int64
# geef            1
# loiled          1
# wellington    233
# dtype: int64
# beeef           4
# loiled          1
# wellington    233
# dtype: int64
# beeff           1
# loiled          1
# wellington    233
# dtype: int64
# beer          9159
# loiled           1
# wellington     233
# dtype: int64
# beeg            1
# loiled          1
# wellington    233
# dtype: int64
# boef            1
# loiled          1
# wellington    233
# dtype: int64
# beff            3
# loiled          1
# wellington    233
# dtype: int64
# loiled          1
# teef            1
# wellington    233
# dtype: int64
# bowled          8
# eef             1
# wellington    233
# dtype: int64
# bowled          8
# deef            1
# wellington    233
# dtype: int64
# bowled          8
# reef           19
# wellington    233
# dtype: int64
# bef             3
# bowled          8
# wellington    233
# dtype: int64
# beefy         541
# bowled          8
# wellington    233
# dtype: int64
# beek            1
# bowled          8
# wellington    233
# dtype: int64
# beel            2
# bowled          8
# wellington    233
# dtype: int64
# bee           241
# bowled          8
# wellington    233
# dtype: int64
# beefs          12
# bowled          8
# wellington    233
# dtype: int64
# bees           57
# bowled          8
# wellington    233
# dtype: int64
# beaf            5
# bowled          8
# wellington    233
# dtype: int64
# beet          1827
# bowled           8
# wellington     233
# dtype: int64
# beez            2
# bowled          8
# wellington    233
# dtype: int64
# beefl           1
# bowled          8
# wellington    233
# dtype: int64
# beep          150
# bowled          8
# wellington    233
# dtype: int64
# bowled          8
# peef            1
# wellington    233
# dtype: int64
# beed           18
# bowled          8
# wellington    233
# dtype: int64
# bowled          8
# geef            1
# wellington    233
# dtype: int64
# beeef           4
# bowled          8
# wellington    233
# dtype: int64
# beeff           1
# bowled          8
# wellington    233
# dtype: int64
# beer          9159
# bowled           8
# wellington     233
# dtype: int64
# beeg            1
# bowled          8
# wellington    233
# dtype: int64
# boef            1
# bowled          8
# wellington    233
# dtype: int64
# beff            3
# bowled          8
# wellington    233
# dtype: int64
# bowled          8
# teef            1
# wellington    233
# dtype: int64
# eef              1
# oiled         5502
# wellington     233
# dtype: int64
# deef             1
# oiled         5502
# wellington     233
# dtype: int64
# oiled         5502
# reef            19
# wellington     233
# dtype: int64
# bef              3
# oiled         5502
# wellington     233
# dtype: int64
# beefy          541
# oiled         5502
# wellington     233
# dtype: int64
# beek             1
# oiled         5502
# wellington     233
# dtype: int64
# beel             2
# oiled         5502
# wellington     233
# dtype: int64
# bee            241
# oiled         5502
# wellington     233
# dtype: int64
# beefs           12
# oiled         5502
# wellington     233
# dtype: int64
# bees            57
# oiled         5502
# wellington     233
# dtype: int64
# beaf             5
# oiled         5502
# wellington     233
# dtype: int64
# beet          1827
# oiled         5502
# wellington     233
# dtype: int64
# beez             2
# oiled         5502
# wellington     233
# dtype: int64
# beefl            1
# oiled         5502
# wellington     233
# dtype: int64
# beep           150
# oiled         5502
# wellington     233
# dtype: int64
# oiled         5502
# peef             1
# wellington     233
# dtype: int64
# beed            18
# oiled         5502
# wellington     233
# dtype: int64
# geef             1
# oiled         5502
# wellington     233
# dtype: int64
# beeef            4
# oiled         5502
# wellington     233
# dtype: int64
# beeff            1
# oiled         5502
# wellington     233
# dtype: int64
# beer          9159
# oiled         5502
# wellington     233
# dtype: int64
# beeg             1
# oiled         5502
# wellington     233
# dtype: int64
# boef             1
# oiled         5502
# wellington     233
# dtype: int64
# beff             3
# oiled         5502
# wellington     233
# dtype: int64
# oiled         5502
# teef             1
# wellington     233
# dtype: int64
# boyled          1
# eef             1
# wellington    233
# dtype: int64
# boyled          1
# deef            1
# wellington    233
# dtype: int64
# boyled          1
# reef           19
# wellington    233
# dtype: int64
# bef             3
# boyled          1
# wellington    233
# dtype: int64
# beefy         541
# boyled          1
# wellington    233
# dtype: int64
# beek            1
# boyled          1
# wellington    233
# dtype: int64
# beel            2
# boyled          1
# wellington    233
# dtype: int64
# bee           241
# boyled          1
# wellington    233
# dtype: int64
# beefs          12
# boyled          1
# wellington    233
# dtype: int64
# bees           57
# boyled          1
# wellington    233
# dtype: int64
# beaf            5
# boyled          1
# wellington    233
# dtype: int64
# beet          1827
# boyled           1
# wellington     233
# dtype: int64
# beez            2
# boyled          1
# wellington    233
# dtype: int64
# beefl           1
# boyled          1
# wellington    233
# dtype: int64
# beep          150
# boyled          1
# wellington    233
# dtype: int64
# boyled          1
# peef            1
# wellington    233
# dtype: int64
# beed           18
# boyled          1
# wellington    233
# dtype: int64
# boyled          1
# geef            1
# wellington    233
# dtype: int64
# beeef           4
# boyled          1
# wellington    233
# dtype: int64
# beeff           1
# boyled          1
# wellington    233
# dtype: int64
# beer          9159
# boyled           1
# wellington     233
# dtype: int64
# beeg            1
# boyled          1
# wellington    233
# dtype: int64
# boef            1
# boyled          1
# wellington    233
# dtype: int64
# beff            3
# boyled          1
# wellington    233
# dtype: int64
# boyled          1
# teef            1
# wellington    233
# dtype: int64
# eef             1
# toiled          2
# wellington    233
# dtype: int64
# deef            1
# toiled          2
# wellington    233
# dtype: int64
# reef           19
# toiled          2
# wellington    233
# dtype: int64
# bef             3
# toiled          2
# wellington    233
# dtype: int64
# beefy         541
# toiled          2
# wellington    233
# dtype: int64
# beek            1
# toiled          2
# wellington    233
# dtype: int64
# beel            2
# toiled          2
# wellington    233
# dtype: int64
# bee           241
# toiled          2
# wellington    233
# dtype: int64
# beefs          12
# toiled          2
# wellington    233
# dtype: int64
# bees           57
# toiled          2
# wellington    233
# dtype: int64
# beaf            5
# toiled          2
# wellington    233
# dtype: int64
# beet          1827
# toiled           2
# wellington     233
# dtype: int64
# beez            2
# toiled          2
# wellington    233
# dtype: int64
# beefl           1
# toiled          2
# wellington    233
# dtype: int64
# beep          150
# toiled          2
# wellington    233
# dtype: int64
# peef            1
# toiled          2
# wellington    233
# dtype: int64
# beed           18
# toiled          2
# wellington    233
# dtype: int64
# geef            1
# toiled          2
# wellington    233
# dtype: int64
# beeef           4
# toiled          2
# wellington    233
# dtype: int64
# beeff           1
# toiled          2
# wellington    233
# dtype: int64
# beer          9159
# toiled           2
# wellington     233
# dtype: int64
# beeg            1
# toiled          2
# wellington    233
# dtype: int64
# boef            1
# toiled          2
# wellington    233
# dtype: int64
# beff            3
# toiled          2
# wellington    233
# dtype: int64
# teef            1
# toiled          2
# wellington    233
# dtype: int64
# eef             1
# foiled        107
# wellington    233
# dtype: int64
# deef            1
# foiled        107
# wellington    233
# dtype: int64
# foiled        107
# reef           19
# wellington    233
# dtype: int64
# bef             3
# foiled        107
# wellington    233
# dtype: int64
# beefy         541
# foiled        107
# wellington    233
# dtype: int64
# beek            1
# foiled        107
# wellington    233
# dtype: int64
# beel            2
# foiled        107
# wellington    233
# dtype: int64
# bee           241
# foiled        107
# wellington    233
# dtype: int64
# beefs          12
# foiled        107
# wellington    233
# dtype: int64
# bees           57
# foiled        107
# wellington    233
# dtype: int64
# beaf            5
# foiled        107
# wellington    233
# dtype: int64
# beet          1827
# foiled         107
# wellington     233
# dtype: int64
# beez            2
# foiled        107
# wellington    233
# dtype: int64
# beefl           1
# foiled        107
# wellington    233
# dtype: int64
# beep          150
# foiled        107
# wellington    233
# dtype: int64
# foiled        107
# peef            1
# wellington    233
# dtype: int64
# beed           18
# foiled        107
# wellington    233
# dtype: int64
# foiled        107
# geef            1
# wellington    233
# dtype: int64
# beeef           4
# foiled        107
# wellington    233
# dtype: int64
# beeff           1
# foiled        107
# wellington    233
# dtype: int64
# beer          9159
# foiled         107
# wellington     233
# dtype: int64
# beeg            1
# foiled        107
# wellington    233
# dtype: int64
# boef            1
# foiled        107
# wellington    233
# dtype: int64
# beff            3
# foiled        107
# wellington    233
# dtype: int64
# foiled        107
# teef            1
# wellington    233
# dtype: int64
# bouled          1
# eef             1
# wellington    233
# dtype: int64
# bouled          1
# deef            1
# wellington    233
# dtype: int64
# bouled          1
# reef           19
# wellington    233
# dtype: int64
# bef             3
# bouled          1
# wellington    233
# dtype: int64
# beefy         541
# bouled          1
# wellington    233
# dtype: int64
# beek            1
# bouled          1
# wellington    233
# dtype: int64
# beel            2
# bouled          1
# wellington    233
# dtype: int64
# bee           241
# bouled          1
# wellington    233
# dtype: int64
# beefs          12
# bouled          1
# wellington    233
# dtype: int64
# bees           57
# bouled          1
# wellington    233
# dtype: int64
# beaf            5
# bouled          1
# wellington    233
# dtype: int64
# beet          1827
# bouled           1
# wellington     233
# dtype: int64
# beez            2
# bouled          1
# wellington    233
# dtype: int64
# beefl           1
# bouled          1
# wellington    233
# dtype: int64
# beep          150
# bouled          1
# wellington    233
# dtype: int64
# bouled          1
# peef            1
# wellington    233
# dtype: int64
# beed           18
# bouled          1
# wellington    233
# dtype: int64
# bouled          1
# geef            1
# wellington    233
# dtype: int64
# beeef           4
# bouled          1
# wellington    233
# dtype: int64
# beeff           1
# bouled          1
# wellington    233
# dtype: int64
# beer          9159
# bouled           1
# wellington     233
# dtype: int64
# beeg            1
# bouled          1
# wellington    233
# dtype: int64
# boef            1
# bouled          1
# wellington    233
# dtype: int64
# beff            3
# bouled          1
# wellington    233
# dtype: int64
# bouled          1
# teef            1
# wellington    233
# dtype: int64
# boile           2
# eef             1
# wellington    233
# dtype: int64
# boile           2
# deef            1
# wellington    233
# dtype: int64
# boile           2
# reef           19
# wellington    233
# dtype: int64
# bef             3
# boile           2
# wellington    233
# dtype: int64
# beefy         541
# boile           2
# wellington    233
# dtype: int64
# beek            1
# boile           2
# wellington    233
# dtype: int64
# beel            2
# boile           2
# wellington    233
# dtype: int64
# bee           241
# boile           2
# wellington    233
# dtype: int64
# beefs          12
# boile           2
# wellington    233
# dtype: int64
# bees           57
# boile           2
# wellington    233
# dtype: int64
# beaf            5
# boile           2
# wellington    233
# dtype: int64
# beet          1827
# boile            2
# wellington     233
# dtype: int64
# beez            2
# boile           2
# wellington    233
# dtype: int64
# beefl           1
# boile           2
# wellington    233
# dtype: int64
# beep          150
# boile           2
# wellington    233
# dtype: int64
# boile           2
# peef            1
# wellington    233
# dtype: int64
# beed           18
# boile           2
# wellington    233
# dtype: int64
# boile           2
# geef            1
# wellington    233
# dtype: int64
# beeef           4
# boile           2
# wellington    233
# dtype: int64
# beeff           1
# boile           2
# wellington    233
# dtype: int64
# beer          9159
# boile            2
# wellington     233
# dtype: int64
# beeg            1
# boile           2
# wellington    233
# dtype: int64
# boef            1
# boile           2
# wellington    233
# dtype: int64
# beff            3
# boile           2
# wellington    233
# dtype: int64
# boile           2
# teef            1
# wellington    233
# dtype: int64
# bolied          2
# eef             1
# wellington    233
# dtype: int64
# bolied          2
# deef            1
# wellington    233
# dtype: int64
# bolied          2
# reef           19
# wellington    233
# dtype: int64
# bef             3
# bolied          2
# wellington    233
# dtype: int64
# beefy         541
# bolied          2
# wellington    233
# dtype: int64
# beek            1
# bolied          2
# wellington    233
# dtype: int64
# beel            2
# bolied          2
# wellington    233
# dtype: int64
# bee           241
# bolied          2
# wellington    233
# dtype: int64
# beefs          12
# bolied          2
# wellington    233
# dtype: int64
# bees           57
# bolied          2
# wellington    233
# dtype: int64
# beaf            5
# bolied          2
# wellington    233
# dtype: int64
# beet          1827
# bolied           2
# wellington     233
# dtype: int64
# beez            2
# bolied          2
# wellington    233
# dtype: int64
# beefl           1
# bolied          2
# wellington    233
# dtype: int64
# beep          150
# bolied          2
# wellington    233
# dtype: int64
# bolied          2
# peef            1
# wellington    233
# dtype: int64
# beed           18
# bolied          2
# wellington    233
# dtype: int64
# bolied          2
# geef            1
# wellington    233
# dtype: int64
# beeef           4
# bolied          2
# wellington    233
# dtype: int64
# beeff           1
# bolied          2
# wellington    233
# dtype: int64
# beer          9159
# bolied           2
# wellington     233
# dtype: int64
# beeg            1
# bolied          2
# wellington    233
# dtype: int64
# boef            1
# bolied          2
# wellington    233
# dtype: int64
# beff            3
# bolied          2
# wellington    233
# dtype: int64
# bolied          2
# teef            1
# wellington    233
# dtype: int64
# coiled         36
# eef             1
# wellington    233
# dtype: int64
# coiled         36
# deef            1
# wellington    233
# dtype: int64
# coiled         36
# reef           19
# wellington    233
# dtype: int64
# bef             3
# coiled         36
# wellington    233
# dtype: int64
# beefy         541
# coiled         36
# wellington    233
# dtype: int64
# beek            1
# coiled         36
# wellington    233
# dtype: int64
# beel            2
# coiled         36
# wellington    233
# dtype: int64
# bee           241
# coiled         36
# wellington    233
# dtype: int64
# beefs          12
# coiled         36
# wellington    233
# dtype: int64
# bees           57
# coiled         36
# wellington    233
# dtype: int64
# beaf            5
# coiled         36
# wellington    233
# dtype: int64
# beet          1827
# coiled          36
# wellington     233
# dtype: int64
# beez            2
# coiled         36
# wellington    233
# dtype: int64
# beefl           1
# coiled         36
# wellington    233
# dtype: int64
# beep          150
# coiled         36
# wellington    233
# dtype: int64
# coiled         36
# peef            1
# wellington    233
# dtype: int64
# beed           18
# coiled         36
# wellington    233
# dtype: int64
# coiled         36
# geef            1
# wellington    233
# dtype: int64
# beeef           4
# coiled         36
# wellington    233
# dtype: int64
# beeff           1
# coiled         36
# wellington    233
# dtype: int64
# beer          9159
# coiled          36
# wellington     233
# dtype: int64
# beeg            1
# coiled         36
# wellington    233
# dtype: int64
# boef            1
# coiled         36
# wellington    233
# dtype: int64
# beff            3
# coiled         36
# wellington    233
# dtype: int64
# coiled         36
# teef            1
# wellington    233
# dtype: int64
# boiles          1
# eef             1
# wellington    233
# dtype: int64
# boiles          1
# deef            1
# wellington    233
# dtype: int64
# boiles          1
# reef           19
# wellington    233
# dtype: int64
# bef             3
# boiles          1
# wellington    233
# dtype: int64
# beefy         541
# boiles          1
# wellington    233
# dtype: int64
# beek            1
# boiles          1
# wellington    233
# dtype: int64
# beel            2
# boiles          1
# wellington    233
# dtype: int64
# bee           241
# boiles          1
# wellington    233
# dtype: int64
# beefs          12
# boiles          1
# wellington    233
# dtype: int64
# bees           57
# boiles          1
# wellington    233
# dtype: int64
# beaf            5
# boiles          1
# wellington    233
# dtype: int64
# beet          1827
# boiles           1
# wellington     233
# dtype: int64
# beez            2
# boiles          1
# wellington    233
# dtype: int64
# beefl           1
# boiles          1
# wellington    233
# dtype: int64
# beep          150
# boiles          1
# wellington    233
# dtype: int64
# boiles          1
# peef            1
# wellington    233
# dtype: int64
# beed           18
# boiles          1
# wellington    233
# dtype: int64
# boiles          1
# geef            1
# wellington    233
# dtype: int64
# beeef           4
# boiles          1
# wellington    233
# dtype: int64
# beeff           1
# boiles          1
# wellington    233
# dtype: int64
# beer          9159
# boiles           1
# wellington     233
# dtype: int64
# beeg            1
# boiles          1
# wellington    233
# dtype: int64
# boef            1
# boiles          1
# wellington    233
# dtype: int64
# beff            3
# boiles          1
# wellington    233
# dtype: int64
# boiles          1
# teef            1
# wellington    233
# dtype: int64
# boild          16
# eef             1
# wellington    233
# dtype: int64
# boild          16
# deef            1
# wellington    233
# dtype: int64
# boild          16
# reef           19
# wellington    233
# dtype: int64
# bef             3
# boild          16
# wellington    233
# dtype: int64
# beefy         541
# boild          16
# wellington    233
# dtype: int64
# beek            1
# boild          16
# wellington    233
# dtype: int64
# beel            2
# boild          16
# wellington    233
# dtype: int64
# bee           241
# boild          16
# wellington    233
# dtype: int64
# beefs          12
# boild          16
# wellington    233
# dtype: int64
# bees           57
# boild          16
# wellington    233
# dtype: int64
# beaf            5
# boild          16
# wellington    233
# dtype: int64
# beet          1827
# boild           16
# wellington     233
# dtype: int64
# beez            2
# boild          16
# wellington    233
# dtype: int64
# beefl           1
# boild          16
# wellington    233
# dtype: int64
# beep          150
# boild          16
# wellington    233
# dtype: int64
# boild          16
# peef            1
# wellington    233
# dtype: int64
# beed           18
# boild          16
# wellington    233
# dtype: int64
# boild          16
# geef            1
# wellington    233
# dtype: int64
# beeef           4
# boild          16
# wellington    233
# dtype: int64
# beeff           1
# boild          16
# wellington    233
# dtype: int64
# beer          9159
# boild           16
# wellington     233
# dtype: int64
# beeg            1
# boild          16
# wellington    233
# dtype: int64
# boef            1
# boild          16
# wellington    233
# dtype: int64
# beff            3
# boild          16
# wellington    233
# dtype: int64
# boild          16
# teef            1
# wellington    233
# dtype: int64
# eef             1
# soiled          8
# wellington    233
# dtype: int64
# deef            1
# soiled          8
# wellington    233
# dtype: int64
# reef           19
# soiled          8
# wellington    233
# dtype: int64
# bef             3
# soiled          8
# wellington    233
# dtype: int64
# beefy         541
# soiled          8
# wellington    233
# dtype: int64
# beek            1
# soiled          8
# wellington    233
# dtype: int64
# beel            2
# soiled          8
# wellington    233
# dtype: int64
# bee           241
# soiled          8
# wellington    233
# dtype: int64
# beefs          12
# soiled          8
# wellington    233
# dtype: int64
# bees           57
# soiled          8
# wellington    233
# dtype: int64
# beaf            5
# soiled          8
# wellington    233
# dtype: int64
# beet          1827
# soiled           8
# wellington     233
# dtype: int64
# beez            2
# soiled          8
# wellington    233
# dtype: int64
# beefl           1
# soiled          8
# wellington    233
# dtype: int64
# beep          150
# soiled          8
# wellington    233
# dtype: int64
# peef            1
# soiled          8
# wellington    233
# dtype: int64
# beed           18
# soiled          8
# wellington    233
# dtype: int64
# geef            1
# soiled          8
# wellington    233
# dtype: int64
# beeef           4
# soiled          8
# wellington    233
# dtype: int64
# beeff           1
# soiled          8
# wellington    233
# dtype: int64
# beer          9159
# soiled           8
# wellington     233
# dtype: int64
# beeg            1
# soiled          8
# wellington    233
# dtype: int64
# boef            1
# soiled          8
# wellington    233
# dtype: int64
# beff            3
# soiled          8
# wellington    233
# dtype: int64
# soiled          8
# teef            1
# wellington    233
# dtype: int64
# boilet          2
# eef             1
# wellington    233
# dtype: int64
# boilet          2
# deef            1
# wellington    233
# dtype: int64
# boilet          2
# reef           19
# wellington    233
# dtype: int64
# bef             3
# boilet          2
# wellington    233
# dtype: int64
# beefy         541
# boilet          2
# wellington    233
# dtype: int64
# beek            1
# boilet          2
# wellington    233
# dtype: int64
# beel            2
# boilet          2
# wellington    233
# dtype: int64
# bee           241
# boilet          2
# wellington    233
# dtype: int64
# beefs          12
# boilet          2
# wellington    233
# dtype: int64
# bees           57
# boilet          2
# wellington    233
# dtype: int64
# beaf            5
# boilet          2
# wellington    233
# dtype: int64
# beet          1827
# boilet           2
# wellington     233
# dtype: int64
# beez            2
# boilet          2
# wellington    233
# dtype: int64
# beefl           1
# boilet          2
# wellington    233
# dtype: int64
# beep          150
# boilet          2
# wellington    233
# dtype: int64
# boilet          2
# peef            1
# wellington    233
# dtype: int64
# beed           18
# boilet          2
# wellington    233
# dtype: int64
# boilet          2
# geef            1
# wellington    233
# dtype: int64
# beeef           4
# boilet          2
# wellington    233
# dtype: int64
# beeff           1
# boilet          2
# wellington    233
# dtype: int64
# beer          9159
# boilet           2
# wellington     233
# dtype: int64
# beeg            1
# boilet          2
# wellington    233
# dtype: int64
# boef            1
# boilet          2
# wellington    233
# dtype: int64
# beff            3
# boilet          2
# wellington    233
# dtype: int64
# boilet          2
# teef            1
# wellington    233
# dtype: int64
# boled           1
# eef             1
# wellington    233
# dtype: int64
# boled           1
# deef            1
# wellington    233
# dtype: int64
# boled           1
# reef           19
# wellington    233
# dtype: int64
# bef             3
# boled           1
# wellington    233
# dtype: int64
# beefy         541
# boled           1
# wellington    233
# dtype: int64
# beek            1
# boled           1
# wellington    233
# dtype: int64
# beel            2
# boled           1
# wellington    233
# dtype: int64
# bee           241
# boled           1
# wellington    233
# dtype: int64
# beefs          12
# boled           1
# wellington    233
# dtype: int64
# bees           57
# boled           1
# wellington    233
# dtype: int64
# beaf            5
# boled           1
# wellington    233
# dtype: int64
# beet          1827
# boled            1
# wellington     233
# dtype: int64
# beez            2
# boled           1
# wellington    233
# dtype: int64
# beefl           1
# boled           1
# wellington    233
# dtype: int64
# beep          150
# boled           1
# wellington    233
# dtype: int64
# boled           1
# peef            1
# wellington    233
# dtype: int64
# beed           18
# boled           1
# wellington    233
# dtype: int64
# boled           1
# geef            1
# wellington    233
# dtype: int64
# beeef           4
# boled           1
# wellington    233
# dtype: int64
# beeff           1
# boled           1
# wellington    233
# dtype: int64
# beer          9159
# boled            1
# wellington     233
# dtype: int64
# beeg            1
# boled           1
# wellington    233
# dtype: int64
# boef            1
# boled           1
# wellington    233
# dtype: int64
# beff            3
# boled           1
# wellington    233
# dtype: int64
# boled           1
# teef            1
# wellington    233
# dtype: int64
# boiler       5457
# eef             1
# wellinton       1
# dtype: int64
# boiler       5457
# deef            1
# wellinton       1
# dtype: int64
# boiler       5457
# reef           19
# wellinton       1
# dtype: int64
# bef             3
# boiler       5457
# wellinton       1
# dtype: int64
# beefy         541
# boiler       5457
# wellinton       1
# dtype: int64
# beek            1
# boiler       5457
# wellinton       1
# dtype: int64
# beel            2
# boiler       5457
# wellinton       1
# dtype: int64
# bee           241
# boiler       5457
# wellinton       1
# dtype: int64
# beefs          12
# boiler       5457
# wellinton       1
# dtype: int64
# bees           57
# boiler       5457
# wellinton       1
# dtype: int64
# beaf            5
# boiler       5457
# wellinton       1
# dtype: int64
# beet         1827
# boiler       5457
# wellinton       1
# dtype: int64
# beez            2
# boiler       5457
# wellinton       1
# dtype: int64
# beefl           1
# boiler       5457
# wellinton       1
# dtype: int64
# beep          150
# boiler       5457
# wellinton       1
# dtype: int64
# boiler       5457
# peef            1
# wellinton       1
# dtype: int64
# beed           18
# boiler       5457
# wellinton       1
# dtype: int64
# boiler       5457
# geef            1
# wellinton       1
# dtype: int64
# beeef           4
# boiler       5457
# wellinton       1
# dtype: int64
# beeff           1
# boiler       5457
# wellinton       1
# dtype: int64
# beer         9159
# boiler       5457
# wellinton       1
# dtype: int64
# beeg            1
# boiler       5457
# wellinton       1
# dtype: int64
# boef            1
# boiler       5457
# wellinton       1
# dtype: int64
# beff            3
# boiler       5457
# wellinton       1
# dtype: int64
# boiler       5457
# teef            1
# wellinton       1
# dtype: int64
# broiled      1691
# eef             1
# wellinton       1
# dtype: int64
# broiled      1691
# deef            1
# wellinton       1
# dtype: int64
# broiled      1691
# reef           19
# wellinton       1
# dtype: int64
# bef             3
# broiled      1691
# wellinton       1
# dtype: int64
# beefy         541
# broiled      1691
# wellinton       1
# dtype: int64
# beek            1
# broiled      1691
# wellinton       1
# dtype: int64
# beel            2
# broiled      1691
# wellinton       1
# dtype: int64
# bee           241
# broiled      1691
# wellinton       1
# dtype: int64
# beefs          12
# broiled      1691
# wellinton       1
# dtype: int64
# bees           57
# broiled      1691
# wellinton       1
# dtype: int64
# beaf            5
# broiled      1691
# wellinton       1
# dtype: int64
# beet         1827
# broiled      1691
# wellinton       1
# dtype: int64
# beez            2
# broiled      1691
# wellinton       1
# dtype: int64
# beefl           1
# broiled      1691
# wellinton       1
# dtype: int64
# beep          150
# broiled      1691
# wellinton       1
# dtype: int64
# broiled      1691
# peef            1
# wellinton       1
# dtype: int64
# beed           18
# broiled      1691
# wellinton       1
# dtype: int64
# broiled      1691
# geef            1
# wellinton       1
# dtype: int64
# beeef           4
# broiled      1691
# wellinton       1
# dtype: int64
# beeff           1
# broiled      1691
# wellinton       1
# dtype: int64
# beer         9159
# broiled      1691
# wellinton       1
# dtype: int64
# beeg            1
# broiled      1691
# wellinton       1
# dtype: int64
# boef            1
# broiled      1691
# wellinton       1
# dtype: int64
# beff            3
# broiled      1691
# wellinton       1
# dtype: int64
# broiled      1691
# teef            1
# wellinton       1
# dtype: int64
# eef          1
# loiled       1
# wellinton    1
# dtype: int64
# deef         1
# loiled       1
# wellinton    1
# dtype: int64
# loiled        1
# reef         19
# wellinton     1
# dtype: int64
# bef          3
# loiled       1
# wellinton    1
# dtype: int64
# beefy        541
# loiled         1
# wellinton      1
# dtype: int64
# beek         1
# loiled       1
# wellinton    1
# dtype: int64
# beel         2
# loiled       1
# wellinton    1
# dtype: int64
# bee          241
# loiled         1
# wellinton      1
# dtype: int64
# beefs        12
# loiled        1
# wellinton     1
# dtype: int64
# bees         57
# loiled        1
# wellinton     1
# dtype: int64
# beaf         5
# loiled       1
# wellinton    1
# dtype: int64
# beet         1827
# loiled          1
# wellinton       1
# dtype: int64
# beez         2
# loiled       1
# wellinton    1
# dtype: int64
# beefl        1
# loiled       1
# wellinton    1
# dtype: int64
# beep         150
# loiled         1
# wellinton      1
# dtype: int64
# loiled       1
# peef         1
# wellinton    1
# dtype: int64
# beed         18
# loiled        1
# wellinton     1
# dtype: int64
# geef         1
# loiled       1
# wellinton    1
# dtype: int64
# beeef        4
# loiled       1
# wellinton    1
# dtype: int64
# beeff        1
# loiled       1
# wellinton    1
# dtype: int64
# beer         9159
# loiled          1
# wellinton       1
# dtype: int64
# beeg         1
# loiled       1
# wellinton    1
# dtype: int64
# boef         1
# loiled       1
# wellinton    1
# dtype: int64
# beff         3
# loiled       1
# wellinton    1
# dtype: int64
# loiled       1
# teef         1
# wellinton    1
# dtype: int64
# bowled       8
# eef          1
# wellinton    1
# dtype: int64
# bowled       8
# deef         1
# wellinton    1
# dtype: int64
# bowled        8
# reef         19
# wellinton     1
# dtype: int64
# bef          3
# bowled       8
# wellinton    1
# dtype: int64
# beefy        541
# bowled         8
# wellinton      1
# dtype: int64
# beek         1
# bowled       8
# wellinton    1
# dtype: int64
# beel         2
# bowled       8
# wellinton    1
# dtype: int64
# bee          241
# bowled         8
# wellinton      1
# dtype: int64
# beefs        12
# bowled        8
# wellinton     1
# dtype: int64
# bees         57
# bowled        8
# wellinton     1
# dtype: int64
# beaf         5
# bowled       8
# wellinton    1
# dtype: int64
# beet         1827
# bowled          8
# wellinton       1
# dtype: int64
# beez         2
# bowled       8
# wellinton    1
# dtype: int64
# beefl        1
# bowled       8
# wellinton    1
# dtype: int64
# beep         150
# bowled         8
# wellinton      1
# dtype: int64
# bowled       8
# peef         1
# wellinton    1
# dtype: int64
# beed         18
# bowled        8
# wellinton     1
# dtype: int64
# bowled       8
# geef         1
# wellinton    1
# dtype: int64
# beeef        4
# bowled       8
# wellinton    1
# dtype: int64
# beeff        1
# bowled       8
# wellinton    1
# dtype: int64
# beer         9159
# bowled          8
# wellinton       1
# dtype: int64
# beeg         1
# bowled       8
# wellinton    1
# dtype: int64
# boef         1
# bowled       8
# wellinton    1
# dtype: int64
# beff         3
# bowled       8
# wellinton    1
# dtype: int64
# bowled       8
# teef         1
# wellinton    1
# dtype: int64
# eef             1
# oiled        5502
# wellinton       1
# dtype: int64
# deef            1
# oiled        5502
# wellinton       1
# dtype: int64
# oiled        5502
# reef           19
# wellinton       1
# dtype: int64
# bef             3
# oiled        5502
# wellinton       1
# dtype: int64
# beefy         541
# oiled        5502
# wellinton       1
# dtype: int64
# beek            1
# oiled        5502
# wellinton       1
# dtype: int64
# beel            2
# oiled        5502
# wellinton       1
# dtype: int64
# bee           241
# oiled        5502
# wellinton       1
# dtype: int64
# beefs          12
# oiled        5502
# wellinton       1
# dtype: int64
# bees           57
# oiled        5502
# wellinton       1
# dtype: int64
# beaf            5
# oiled        5502
# wellinton       1
# dtype: int64
# beet         1827
# oiled        5502
# wellinton       1
# dtype: int64
# beez            2
# oiled        5502
# wellinton       1
# dtype: int64
# beefl           1
# oiled        5502
# wellinton       1
# dtype: int64
# beep          150
# oiled        5502
# wellinton       1
# dtype: int64
# oiled        5502
# peef            1
# wellinton       1
# dtype: int64
# beed           18
# oiled        5502
# wellinton       1
# dtype: int64
# geef            1
# oiled        5502
# wellinton       1
# dtype: int64
# beeef           4
# oiled        5502
# wellinton       1
# dtype: int64
# beeff           1
# oiled        5502
# wellinton       1
# dtype: int64
# beer         9159
# oiled        5502
# wellinton       1
# dtype: int64
# beeg            1
# oiled        5502
# wellinton       1
# dtype: int64
# boef            1
# oiled        5502
# wellinton       1
# dtype: int64
# beff            3
# oiled        5502
# wellinton       1
# dtype: int64
# oiled        5502
# teef            1
# wellinton       1
# dtype: int64
# boyled       1
# eef          1
# wellinton    1
# dtype: int64
# boyled       1
# deef         1
# wellinton    1
# dtype: int64
# boyled        1
# reef         19
# wellinton     1
# dtype: int64
# bef          3
# boyled       1
# wellinton    1
# dtype: int64
# beefy        541
# boyled         1
# wellinton      1
# dtype: int64
# beek         1
# boyled       1
# wellinton    1
# dtype: int64
# beel         2
# boyled       1
# wellinton    1
# dtype: int64
# bee          241
# boyled         1
# wellinton      1
# dtype: int64
# beefs        12
# boyled        1
# wellinton     1
# dtype: int64
# bees         57
# boyled        1
# wellinton     1
# dtype: int64
# beaf         5
# boyled       1
# wellinton    1
# dtype: int64
# beet         1827
# boyled          1
# wellinton       1
# dtype: int64
# beez         2
# boyled       1
# wellinton    1
# dtype: int64
# beefl        1
# boyled       1
# wellinton    1
# dtype: int64
# beep         150
# boyled         1
# wellinton      1
# dtype: int64
# boyled       1
# peef         1
# wellinton    1
# dtype: int64
# beed         18
# boyled        1
# wellinton     1
# dtype: int64
# boyled       1
# geef         1
# wellinton    1
# dtype: int64
# beeef        4
# boyled       1
# wellinton    1
# dtype: int64
# beeff        1
# boyled       1
# wellinton    1
# dtype: int64
# beer         9159
# boyled          1
# wellinton       1
# dtype: int64
# beeg         1
# boyled       1
# wellinton    1
# dtype: int64
# boef         1
# boyled       1
# wellinton    1
# dtype: int64
# beff         3
# boyled       1
# wellinton    1
# dtype: int64
# boyled       1
# teef         1
# wellinton    1
# dtype: int64
# eef          1
# toiled       2
# wellinton    1
# dtype: int64
# deef         1
# toiled       2
# wellinton    1
# dtype: int64
# reef         19
# toiled        2
# wellinton     1
# dtype: int64
# bef          3
# toiled       2
# wellinton    1
# dtype: int64
# beefy        541
# toiled         2
# wellinton      1
# dtype: int64
# beek         1
# toiled       2
# wellinton    1
# dtype: int64
# beel         2
# toiled       2
# wellinton    1
# dtype: int64
# bee          241
# toiled         2
# wellinton      1
# dtype: int64
# beefs        12
# toiled        2
# wellinton     1
# dtype: int64
# bees         57
# toiled        2
# wellinton     1
# dtype: int64
# beaf         5
# toiled       2
# wellinton    1
# dtype: int64
# beet         1827
# toiled          2
# wellinton       1
# dtype: int64
# beez         2
# toiled       2
# wellinton    1
# dtype: int64
# beefl        1
# toiled       2
# wellinton    1
# dtype: int64
# beep         150
# toiled         2
# wellinton      1
# dtype: int64
# peef         1
# toiled       2
# wellinton    1
# dtype: int64
# beed         18
# toiled        2
# wellinton     1
# dtype: int64
# geef         1
# toiled       2
# wellinton    1
# dtype: int64
# beeef        4
# toiled       2
# wellinton    1
# dtype: int64
# beeff        1
# toiled       2
# wellinton    1
# dtype: int64
# beer         9159
# toiled          2
# wellinton       1
# dtype: int64
# beeg         1
# toiled       2
# wellinton    1
# dtype: int64
# boef         1
# toiled       2
# wellinton    1
# dtype: int64
# beff         3
# toiled       2
# wellinton    1
# dtype: int64
# teef         1
# toiled       2
# wellinton    1
# dtype: int64
# eef            1
# foiled       107
# wellinton      1
# dtype: int64
# deef           1
# foiled       107
# wellinton      1
# dtype: int64
# foiled       107
# reef          19
# wellinton      1
# dtype: int64
# bef            3
# foiled       107
# wellinton      1
# dtype: int64
# beefy        541
# foiled       107
# wellinton      1
# dtype: int64
# beek           1
# foiled       107
# wellinton      1
# dtype: int64
# beel           2
# foiled       107
# wellinton      1
# dtype: int64
# bee          241
# foiled       107
# wellinton      1
# dtype: int64
# beefs         12
# foiled       107
# wellinton      1
# dtype: int64
# bees          57
# foiled       107
# wellinton      1
# dtype: int64
# beaf           5
# foiled       107
# wellinton      1
# dtype: int64
# beet         1827
# foiled        107
# wellinton       1
# dtype: int64
# beez           2
# foiled       107
# wellinton      1
# dtype: int64
# beefl          1
# foiled       107
# wellinton      1
# dtype: int64
# beep         150
# foiled       107
# wellinton      1
# dtype: int64
# foiled       107
# peef           1
# wellinton      1
# dtype: int64
# beed          18
# foiled       107
# wellinton      1
# dtype: int64
# foiled       107
# geef           1
# wellinton      1
# dtype: int64
# beeef          4
# foiled       107
# wellinton      1
# dtype: int64
# beeff          1
# foiled       107
# wellinton      1
# dtype: int64
# beer         9159
# foiled        107
# wellinton       1
# dtype: int64
# beeg           1
# foiled       107
# wellinton      1
# dtype: int64
# boef           1
# foiled       107
# wellinton      1
# dtype: int64
# beff           3
# foiled       107
# wellinton      1
# dtype: int64
# foiled       107
# teef           1
# wellinton      1
# dtype: int64
# bouled       1
# eef          1
# wellinton    1
# dtype: int64
# bouled       1
# deef         1
# wellinton    1
# dtype: int64
# bouled        1
# reef         19
# wellinton     1
# dtype: int64
# bef          3
# bouled       1
# wellinton    1
# dtype: int64
# beefy        541
# bouled         1
# wellinton      1
# dtype: int64
# beek         1
# bouled       1
# wellinton    1
# dtype: int64
# beel         2
# bouled       1
# wellinton    1
# dtype: int64
# bee          241
# bouled         1
# wellinton      1
# dtype: int64
# beefs        12
# bouled        1
# wellinton     1
# dtype: int64
# bees         57
# bouled        1
# wellinton     1
# dtype: int64
# beaf         5
# bouled       1
# wellinton    1
# dtype: int64
# beet         1827
# bouled          1
# wellinton       1
# dtype: int64
# beez         2
# bouled       1
# wellinton    1
# dtype: int64
# beefl        1
# bouled       1
# wellinton    1
# dtype: int64
# beep         150
# bouled         1
# wellinton      1
# dtype: int64
# bouled       1
# peef         1
# wellinton    1
# dtype: int64
# beed         18
# bouled        1
# wellinton     1
# dtype: int64
# bouled       1
# geef         1
# wellinton    1
# dtype: int64
# beeef        4
# bouled       1
# wellinton    1
# dtype: int64
# beeff        1
# bouled       1
# wellinton    1
# dtype: int64
# beer         9159
# bouled          1
# wellinton       1
# dtype: int64
# beeg         1
# bouled       1
# wellinton    1
# dtype: int64
# boef         1
# bouled       1
# wellinton    1
# dtype: int64
# beff         3
# bouled       1
# wellinton    1
# dtype: int64
# bouled       1
# teef         1
# wellinton    1
# dtype: int64
# boile        2
# eef          1
# wellinton    1
# dtype: int64
# boile        2
# deef         1
# wellinton    1
# dtype: int64
# boile         2
# reef         19
# wellinton     1
# dtype: int64
# bef          3
# boile        2
# wellinton    1
# dtype: int64
# beefy        541
# boile          2
# wellinton      1
# dtype: int64
# beek         1
# boile        2
# wellinton    1
# dtype: int64
# beel         2
# boile        2
# wellinton    1
# dtype: int64
# bee          241
# boile          2
# wellinton      1
# dtype: int64
# beefs        12
# boile         2
# wellinton     1
# dtype: int64
# bees         57
# boile         2
# wellinton     1
# dtype: int64
# beaf         5
# boile        2
# wellinton    1
# dtype: int64
# beet         1827
# boile           2
# wellinton       1
# dtype: int64
# beez         2
# boile        2
# wellinton    1
# dtype: int64
# beefl        1
# boile        2
# wellinton    1
# dtype: int64
# beep         150
# boile          2
# wellinton      1
# dtype: int64
# boile        2
# peef         1
# wellinton    1
# dtype: int64
# beed         18
# boile         2
# wellinton     1
# dtype: int64
# boile        2
# geef         1
# wellinton    1
# dtype: int64
# beeef        4
# boile        2
# wellinton    1
# dtype: int64
# beeff        1
# boile        2
# wellinton    1
# dtype: int64
# beer         9159
# boile           2
# wellinton       1
# dtype: int64
# beeg         1
# boile        2
# wellinton    1
# dtype: int64
# boef         1
# boile        2
# wellinton    1
# dtype: int64
# beff         3
# boile        2
# wellinton    1
# dtype: int64
# boile        2
# teef         1
# wellinton    1
# dtype: int64
# bolied       2
# eef          1
# wellinton    1
# dtype: int64
# bolied       2
# deef         1
# wellinton    1
# dtype: int64
# bolied        2
# reef         19
# wellinton     1
# dtype: int64
# bef          3
# bolied       2
# wellinton    1
# dtype: int64
# beefy        541
# bolied         2
# wellinton      1
# dtype: int64
# beek         1
# bolied       2
# wellinton    1
# dtype: int64
# beel         2
# bolied       2
# wellinton    1
# dtype: int64
# bee          241
# bolied         2
# wellinton      1
# dtype: int64
# beefs        12
# bolied        2
# wellinton     1
# dtype: int64
# bees         57
# bolied        2
# wellinton     1
# dtype: int64
# beaf         5
# bolied       2
# wellinton    1
# dtype: int64
# beet         1827
# bolied          2
# wellinton       1
# dtype: int64
# beez         2
# bolied       2
# wellinton    1
# dtype: int64
# beefl        1
# bolied       2
# wellinton    1
# dtype: int64
# beep         150
# bolied         2
# wellinton      1
# dtype: int64
# bolied       2
# peef         1
# wellinton    1
# dtype: int64
# beed         18
# bolied        2
# wellinton     1
# dtype: int64
# bolied       2
# geef         1
# wellinton    1
# dtype: int64
# beeef        4
# bolied       2
# wellinton    1
# dtype: int64
# beeff        1
# bolied       2
# wellinton    1
# dtype: int64
# beer         9159
# bolied          2
# wellinton       1
# dtype: int64
# beeg         1
# bolied       2
# wellinton    1
# dtype: int64
# boef         1
# bolied       2
# wellinton    1
# dtype: int64
# beff         3
# bolied       2
# wellinton    1
# dtype: int64
# bolied       2
# teef         1
# wellinton    1
# dtype: int64
# coiled       36
# eef           1
# wellinton     1
# dtype: int64
# coiled       36
# deef          1
# wellinton     1
# dtype: int64
# coiled       36
# reef         19
# wellinton     1
# dtype: int64
# bef           3
# coiled       36
# wellinton     1
# dtype: int64
# beefy        541
# coiled        36
# wellinton      1
# dtype: int64
# beek          1
# coiled       36
# wellinton     1
# dtype: int64
# beel          2
# coiled       36
# wellinton     1
# dtype: int64
# bee          241
# coiled        36
# wellinton      1
# dtype: int64
# beefs        12
# coiled       36
# wellinton     1
# dtype: int64
# bees         57
# coiled       36
# wellinton     1
# dtype: int64
# beaf          5
# coiled       36
# wellinton     1
# dtype: int64
# beet         1827
# coiled         36
# wellinton       1
# dtype: int64
# beez          2
# coiled       36
# wellinton     1
# dtype: int64
# beefl         1
# coiled       36
# wellinton     1
# dtype: int64
# beep         150
# coiled        36
# wellinton      1
# dtype: int64
# coiled       36
# peef          1
# wellinton     1
# dtype: int64
# beed         18
# coiled       36
# wellinton     1
# dtype: int64
# coiled       36
# geef          1
# wellinton     1
# dtype: int64
# beeef         4
# coiled       36
# wellinton     1
# dtype: int64
# beeff         1
# coiled       36
# wellinton     1
# dtype: int64
# beer         9159
# coiled         36
# wellinton       1
# dtype: int64
# beeg          1
# coiled       36
# wellinton     1
# dtype: int64
# boef          1
# coiled       36
# wellinton     1
# dtype: int64
# beff          3
# coiled       36
# wellinton     1
# dtype: int64
# coiled       36
# teef          1
# wellinton     1
# dtype: int64
# boiles       1
# eef          1
# wellinton    1
# dtype: int64
# boiles       1
# deef         1
# wellinton    1
# dtype: int64
# boiles        1
# reef         19
# wellinton     1
# dtype: int64
# bef          3
# boiles       1
# wellinton    1
# dtype: int64
# beefy        541
# boiles         1
# wellinton      1
# dtype: int64
# beek         1
# boiles       1
# wellinton    1
# dtype: int64
# beel         2
# boiles       1
# wellinton    1
# dtype: int64
# bee          241
# boiles         1
# wellinton      1
# dtype: int64
# beefs        12
# boiles        1
# wellinton     1
# dtype: int64
# bees         57
# boiles        1
# wellinton     1
# dtype: int64
# beaf         5
# boiles       1
# wellinton    1
# dtype: int64
# beet         1827
# boiles          1
# wellinton       1
# dtype: int64
# beez         2
# boiles       1
# wellinton    1
# dtype: int64
# beefl        1
# boiles       1
# wellinton    1
# dtype: int64
# beep         150
# boiles         1
# wellinton      1
# dtype: int64
# boiles       1
# peef         1
# wellinton    1
# dtype: int64
# beed         18
# boiles        1
# wellinton     1
# dtype: int64
# boiles       1
# geef         1
# wellinton    1
# dtype: int64
# beeef        4
# boiles       1
# wellinton    1
# dtype: int64
# beeff        1
# boiles       1
# wellinton    1
# dtype: int64
# beer         9159
# boiles          1
# wellinton       1
# dtype: int64
# beeg         1
# boiles       1
# wellinton    1
# dtype: int64
# boef         1
# boiles       1
# wellinton    1
# dtype: int64
# beff         3
# boiles       1
# wellinton    1
# dtype: int64
# boiles       1
# teef         1
# wellinton    1
# dtype: int64
# boild        16
# eef           1
# wellinton     1
# dtype: int64
# boild        16
# deef          1
# wellinton     1
# dtype: int64
# boild        16
# reef         19
# wellinton     1
# dtype: int64
# bef           3
# boild        16
# wellinton     1
# dtype: int64
# beefy        541
# boild         16
# wellinton      1
# dtype: int64
# beek          1
# boild        16
# wellinton     1
# dtype: int64
# beel          2
# boild        16
# wellinton     1
# dtype: int64
# bee          241
# boild         16
# wellinton      1
# dtype: int64
# beefs        12
# boild        16
# wellinton     1
# dtype: int64
# bees         57
# boild        16
# wellinton     1
# dtype: int64
# beaf          5
# boild        16
# wellinton     1
# dtype: int64
# beet         1827
# boild          16
# wellinton       1
# dtype: int64
# beez          2
# boild        16
# wellinton     1
# dtype: int64
# beefl         1
# boild        16
# wellinton     1
# dtype: int64
# beep         150
# boild         16
# wellinton      1
# dtype: int64
# boild        16
# peef          1
# wellinton     1
# dtype: int64
# beed         18
# boild        16
# wellinton     1
# dtype: int64
# boild        16
# geef          1
# wellinton     1
# dtype: int64
# beeef         4
# boild        16
# wellinton     1
# dtype: int64
# beeff         1
# boild        16
# wellinton     1
# dtype: int64
# beer         9159
# boild          16
# wellinton       1
# dtype: int64
# beeg          1
# boild        16
# wellinton     1
# dtype: int64
# boef          1
# boild        16
# wellinton     1
# dtype: int64
# beff          3
# boild        16
# wellinton     1
# dtype: int64
# boild        16
# teef          1
# wellinton     1
# dtype: int64
# eef          1
# soiled       8
# wellinton    1
# dtype: int64
# deef         1
# soiled       8
# wellinton    1
# dtype: int64
# reef         19
# soiled        8
# wellinton     1
# dtype: int64
# bef          3
# soiled       8
# wellinton    1
# dtype: int64
# beefy        541
# soiled         8
# wellinton      1
# dtype: int64
# beek         1
# soiled       8
# wellinton    1
# dtype: int64
# beel         2
# soiled       8
# wellinton    1
# dtype: int64
# bee          241
# soiled         8
# wellinton      1
# dtype: int64
# beefs        12
# soiled        8
# wellinton     1
# dtype: int64
# bees         57
# soiled        8
# wellinton     1
# dtype: int64
# beaf         5
# soiled       8
# wellinton    1
# dtype: int64
# beet         1827
# soiled          8
# wellinton       1
# dtype: int64
# beez         2
# soiled       8
# wellinton    1
# dtype: int64
# beefl        1
# soiled       8
# wellinton    1
# dtype: int64
# beep         150
# soiled         8
# wellinton      1
# dtype: int64
# peef         1
# soiled       8
# wellinton    1
# dtype: int64
# beed         18
# soiled        8
# wellinton     1
# dtype: int64
# geef         1
# soiled       8
# wellinton    1
# dtype: int64
# beeef        4
# soiled       8
# wellinton    1
# dtype: int64
# beeff        1
# soiled       8
# wellinton    1
# dtype: int64
# beer         9159
# soiled          8
# wellinton       1
# dtype: int64
# beeg         1
# soiled       8
# wellinton    1
# dtype: int64
# boef         1
# soiled       8
# wellinton    1
# dtype: int64
# beff         3
# soiled       8
# wellinton    1
# dtype: int64
# soiled       8
# teef         1
# wellinton    1
# dtype: int64
# boilet       2
# eef          1
# wellinton    1
# dtype: int64
# boilet       2
# deef         1
# wellinton    1
# dtype: int64
# boilet        2
# reef         19
# wellinton     1
# dtype: int64
# bef          3
# boilet       2
# wellinton    1
# dtype: int64
# beefy        541
# boilet         2
# wellinton      1
# dtype: int64
# beek         1
# boilet       2
# wellinton    1
# dtype: int64
# beel         2
# boilet       2
# wellinton    1
# dtype: int64
# bee          241
# boilet         2
# wellinton      1
# dtype: int64
# beefs        12
# boilet        2
# wellinton     1
# dtype: int64
# bees         57
# boilet        2
# wellinton     1
# dtype: int64
# beaf         5
# boilet       2
# wellinton    1
# dtype: int64
# beet         1827
# boilet          2
# wellinton       1
# dtype: int64
# beez         2
# boilet       2
# wellinton    1
# dtype: int64
# beefl        1
# boilet       2
# wellinton    1
# dtype: int64
# beep         150
# boilet         2
# wellinton      1
# dtype: int64
# boilet       2
# peef         1
# wellinton    1
# dtype: int64
# beed         18
# boilet        2
# wellinton     1
# dtype: int64
# boilet       2
# geef         1
# wellinton    1
# dtype: int64
# beeef        4
# boilet       2
# wellinton    1
# dtype: int64
# beeff        1
# boilet       2
# wellinton    1
# dtype: int64
# beer         9159
# boilet          2
# wellinton       1
# dtype: int64
# beeg         1
# boilet       2
# wellinton    1
# dtype: int64
# boef         1
# boilet       2
# wellinton    1
# dtype: int64
# beff         3
# boilet       2
# wellinton    1
# dtype: int64
# boilet       2
# teef         1
# wellinton    1
# dtype: int64
# boled        1
# eef          1
# wellinton    1
# dtype: int64
# boled        1
# deef         1
# wellinton    1
# dtype: int64
# boled         1
# reef         19
# wellinton     1
# dtype: int64
# bef          3
# boled        1
# wellinton    1
# dtype: int64
# beefy        541
# boled          1
# wellinton      1
# dtype: int64
# beek         1
# boled        1
# wellinton    1
# dtype: int64
# beel         2
# boled        1
# wellinton    1
# dtype: int64
# bee          241
# boled          1
# wellinton      1
# dtype: int64
# beefs        12
# boled         1
# wellinton     1
# dtype: int64
# bees         57
# boled         1
# wellinton     1
# dtype: int64
# beaf         5
# boled        1
# wellinton    1
# dtype: int64
# beet         1827
# boled           1
# wellinton       1
# dtype: int64
# beez         2
# boled        1
# wellinton    1
# dtype: int64
# beefl        1
# boled        1
# wellinton    1
# dtype: int64
# beep         150
# boled          1
# wellinton      1
# dtype: int64
# boled        1
# peef         1
# wellinton    1
# dtype: int64
# beed         18
# boled         1
# wellinton     1
# dtype: int64
# boled        1
# geef         1
# wellinton    1
# dtype: int64
# beeef        4
# boled        1
# wellinton    1
# dtype: int64
# beeff        1
# boled        1
# wellinton    1
# dtype: int64
# beer         9159
# boled           1
# wellinton       1
# dtype: int64
# beeg         1
# boled        1
# wellinton    1
# dtype: int64
# boef         1
# boled        1
# wellinton    1
# dtype: int64
# beff         3
# boled        1
# wellinton    1
# dtype: int64
# boled        1
# teef         1
# wellinton    1
# dtype: int64
#                          score
# boiler eef wellington      1.0
# beefs boyled wellinton     1.0
# beaf boyled wellinton      1.0
# beet boyled wellinton      1.0
# beez boyled wellinton      1.0
# ...                        ...
# beet coiled wellington     1.0
# beez coiled wellington     1.0
# beefl coiled wellington    1.0
# beep coiled wellington     1.0
# boled teef wellinton       1.0
#
# [850 rows x 1 columns]

# %%
[round for round in np.array(c).T]
# Out:
# [['boiler eef',
#   'boiler deef',
#   'boiler reef',
#   'boiler bef',
#   'boiler beefy',
#   'boiler beek',
#   'boiler beel',
#   'boiler bee',
#   'boiler beefs',
#   'boiler bees',
#   'boiler beaf',
#   'boiler beet',
#   'boiler beez',
#   'boiler beefl',
#   'boiler beep',
#   'boiler peef',
#   'boiler beed',
#   'boiler geef',
#   'boiler beeef',
#   'boiler beeff',
#   'boiler beer',
#   'boiler beeg',
#   'boiler boef',
#   'boiler beff',
#   'boiler teef',
#   'boiler beef',
#   'broiled eef',
#   'broiled deef',
#   'broiled reef',
#   'broiled bef',
#   'broiled beefy',
#   'broiled beek',
#   'broiled beel',
#   'broiled bee',
#   'broiled beefs',
#   'broiled bees',
#   'broiled beaf',
#   'broiled beet',
#   'broiled beez',
#   'broiled beefl',
#   'broiled beep',
#   'broiled peef',
#   'broiled beed',
#   'broiled geef',
#   'broiled beeef',
#   'broiled beeff',
#   'broiled beer',
#   'broiled beeg',
#   'broiled boef',
#   'broiled beff',
#   'broiled teef',
#   'broiled beef',
#   'loiled eef',
#   'loiled deef',
#   'loiled reef',
#   'loiled bef',
#   'loiled beefy',
#   'loiled beek',
#   'loiled beel',
#   'loiled bee',
#   'loiled beefs',
#   'loiled bees',
#   'loiled beaf',
#   'loiled beet',
#   'loiled beez',
#   'loiled beefl',
#   'loiled beep',
#   'loiled peef',
#   'loiled beed',
#   'loiled geef',
#   'loiled beeef',
#   'loiled beeff',
#   'loiled beer',
#   'loiled beeg',
#   'loiled boef',
#   'loiled beff',
#   'loiled teef',
#   'loiled beef',
#   'bowled eef',
#   'bowled deef',
#   'bowled reef',
#   'bowled bef',
#   'bowled beefy',
#   'bowled beek',
#   'bowled beel',
#   'bowled bee',
#   'bowled beefs',
#   'bowled bees',
#   'bowled beaf',
#   'bowled beet',
#   'bowled beez',
#   'bowled beefl',
#   'bowled beep',
#   'bowled peef',
#   'bowled beed',
#   'bowled geef',
#   'bowled beeef',
#   'bowled beeff',
#   'bowled beer',
#   'bowled beeg',
#   'bowled boef',
#   'bowled beff',
#   'bowled teef',
#   'bowled beef',
#   'oiled eef',
#   'oiled deef',
#   'oiled reef',
#   'oiled bef',
#   'oiled beefy',
#   'oiled beek',
#   'oiled beel',
#   'oiled bee',
#   'oiled beefs',
#   'oiled bees',
#   'oiled beaf',
#   'oiled beet',
#   'oiled beez',
#   'oiled beefl',
#   'oiled beep',
#   'oiled peef',
#   'oiled beed',
#   'oiled geef',
#   'oiled beeef',
#   'oiled beeff',
#   'oiled beer',
#   'oiled beeg',
#   'oiled boef',
#   'oiled beff',
#   'oiled teef',
#   'oiled beef',
#   'boyled eef',
#   'boyled deef',
#   'boyled reef',
#   'boyled bef',
#   'boyled beefy',
#   'boyled beek',
#   'boyled beel',
#   'boyled bee',
#   'boyled beefs',
#   'boyled bees',
#   'boyled beaf',
#   'boyled beet',
#   'boyled beez',
#   'boyled beefl',
#   'boyled beep',
#   'boyled peef',
#   'boyled beed',
#   'boyled geef',
#   'boyled beeef',
#   'boyled beeff',
#   'boyled beer',
#   'boyled beeg',
#   'boyled boef',
#   'boyled beff',
#   'boyled teef',
#   'boyled beef',
#   'toiled eef',
#   'toiled deef',
#   'toiled reef',
#   'toiled bef',
#   'toiled beefy',
#   'toiled beek',
#   'toiled beel',
#   'toiled bee',
#   'toiled beefs',
#   'toiled bees',
#   'toiled beaf',
#   'toiled beet',
#   'toiled beez',
#   'toiled beefl',
#   'toiled beep',
#   'toiled peef',
#   'toiled beed',
#   'toiled geef',
#   'toiled beeef',
#   'toiled beeff',
#   'toiled beer',
#   'toiled beeg',
#   'toiled boef',
#   'toiled beff',
#   'toiled teef',
#   'toiled beef',
#   'foiled eef',
#   'foiled deef',
#   'foiled reef',
#   'foiled bef',
#   'foiled beefy',
#   'foiled beek',
#   'foiled beel',
#   'foiled bee',
#   'foiled beefs',
#   'foiled bees',
#   'foiled beaf',
#   'foiled beet',
#   'foiled beez',
#   'foiled beefl',
#   'foiled beep',
#   'foiled peef',
#   'foiled beed',
#   'foiled geef',
#   'foiled beeef',
#   'foiled beeff',
#   'foiled beer',
#   'foiled beeg',
#   'foiled boef',
#   'foiled beff',
#   'foiled teef',
#   'foiled beef',
#   'bouled eef',
#   'bouled deef',
#   'bouled reef',
#   'bouled bef',
#   'bouled beefy',
#   'bouled beek',
#   'bouled beel',
#   'bouled bee',
#   'bouled beefs',
#   'bouled bees',
#   'bouled beaf',
#   'bouled beet',
#   'bouled beez',
#   'bouled beefl',
#   'bouled beep',
#   'bouled peef',
#   'bouled beed',
#   'bouled geef',
#   'bouled beeef',
#   'bouled beeff',
#   'bouled beer',
#   'bouled beeg',
#   'bouled boef',
#   'bouled beff',
#   'bouled teef',
#   'bouled beef',
#   'boile eef',
#   'boile deef',
#   'boile reef',
#   'boile bef',
#   'boile beefy',
#   'boile beek',
#   'boile beel',
#   'boile bee',
#   'boile beefs',
#   'boile bees',
#   'boile beaf',
#   'boile beet',
#   'boile beez',
#   'boile beefl',
#   'boile beep',
#   'boile peef',
#   'boile beed',
#   'boile geef',
#   'boile beeef',
#   'boile beeff',
#   'boile beer',
#   'boile beeg',
#   'boile boef',
#   'boile beff',
#   'boile teef',
#   'boile beef',
#   'bolied eef',
#   'bolied deef',
#   'bolied reef',
#   'bolied bef',
#   'bolied beefy',
#   'bolied beek',
#   'bolied beel',
#   'bolied bee',
#   'bolied beefs',
#   'bolied bees',
#   'bolied beaf',
#   'bolied beet',
#   'bolied beez',
#   'bolied beefl',
#   'bolied beep',
#   'bolied peef',
#   'bolied beed',
#   'bolied geef',
#   'bolied beeef',
#   'bolied beeff',
#   'bolied beer',
#   'bolied beeg',
#   'bolied boef',
#   'bolied beff',
#   'bolied teef',
#   'bolied beef',
#   'coiled eef',
#   'coiled deef',
#   'coiled reef',
#   'coiled bef',
#   'coiled beefy',
#   'coiled beek',
#   'coiled beel',
#   'coiled bee',
#   'coiled beefs',
#   'coiled bees',
#   'coiled beaf',
#   'coiled beet',
#   'coiled beez',
#   'coiled beefl',
#   'coiled beep',
#   'coiled peef',
#   'coiled beed',
#   'coiled geef',
#   'coiled beeef',
#   'coiled beeff',
#   'coiled beer',
#   'coiled beeg',
#   'coiled boef',
#   'coiled beff',
#   'coiled teef',
#   'coiled beef',
#   'boiles eef',
#   'boiles deef',
#   'boiles reef',
#   'boiles bef',
#   'boiles beefy',
#   'boiles beek',
#   'boiles beel',
#   'boiles bee',
#   'boiles beefs',
#   'boiles bees',
#   'boiles beaf',
#   'boiles beet',
#   'boiles beez',
#   'boiles beefl',
#   'boiles beep',
#   'boiles peef',
#   'boiles beed',
#   'boiles geef',
#   'boiles beeef',
#   'boiles beeff',
#   'boiles beer',
#   'boiles beeg',
#   'boiles boef',
#   'boiles beff',
#   'boiles teef',
#   'boiles beef',
#   'boild eef',
#   'boild deef',
#   'boild reef',
#   'boild bef',
#   'boild beefy',
#   'boild beek',
#   'boild beel',
#   'boild bee',
#   'boild beefs',
#   'boild bees',
#   'boild beaf',
#   'boild beet',
#   'boild beez',
#   'boild beefl',
#   'boild beep',
#   'boild peef',
#   'boild beed',
#   'boild geef',
#   'boild beeef',
#   'boild beeff',
#   'boild beer',
#   'boild beeg',
#   'boild boef',
#   'boild beff',
#   'boild teef',
#   'boild beef',
#   'soiled eef',
#   'soiled deef',
#   'soiled reef',
#   'soiled bef',
#   'soiled beefy',
#   'soiled beek',
#   'soiled beel',
#   'soiled bee',
#   'soiled beefs',
#   'soiled bees',
#   'soiled beaf',
#   'soiled beet',
#   'soiled beez',
#   'soiled beefl',
#   'soiled beep',
#   'soiled peef',
#   'soiled beed',
#   'soiled geef',
#   'soiled beeef',
#   'soiled beeff',
#   'soiled beer',
#   'soiled beeg',
#   'soiled boef',
#   'soiled beff',
#   'soiled teef',
#   'soiled beef',
#   'boilet eef',
#   'boilet deef',
#   'boilet reef',
#   'boilet bef',
#   'boilet beefy',
#   'boilet beek',
#   'boilet beel',
#   'boilet bee',
#   'boilet beefs',
#   'boilet bees',
#   'boilet beaf',
#   'boilet beet',
#   'boilet beez',
#   'boilet beefl',
#   'boilet beep',
#   'boilet peef',
#   'boilet beed',
#   'boilet geef',
#   'boilet beeef',
#   'boilet beeff',
#   'boilet beer',
#   'boilet beeg',
#   'boilet boef',
#   'boilet beff',
#   'boilet teef',
#   'boilet beef',
#   'boled eef',
#   'boled deef',
#   'boled reef',
#   'boled bef',
#   'boled beefy',
#   'boled beek',
#   'boled beel',
#   'boled bee',
#   'boled beefs',
#   'boled bees',
#   'boled beaf',
#   'boled beet',
#   'boled beez',
#   'boled beefl',
#   'boled beep',
#   'boled peef',
#   'boled beed',
#   'boled geef',
#   'boled beeef',
#   'boled beeff',
#   'boled beer',
#   'boled beeg',
#   'boled boef',
#   'boled beff',
#   'boled teef',
#   'boled beef',
#   'boiled eef',
#   'boiled deef',
#   'boiled reef',
#   'boiled bef',
#   'boiled beefy',
#   'boiled beek',
#   'boiled beel',
#   'boiled bee',
#   'boiled beefs',
#   'boiled bees',
#   'boiled beaf',
#   'boiled beet',
#   'boiled beez',
#   'boiled beefl',
#   'boiled beep',
#   'boiled peef',
#   'boiled beed',
#   'boiled geef',
#   'boiled beeef',
#   'boiled beeff',
#   'boiled beer',
#   'boiled beeg',
#   'boiled boef',
#   'boiled beff',
#   'boiled teef',
#   'boiled beef',
#   'boiler eef',
#   'boiler deef',
#   'boiler reef',
#   'boiler bef',
#   'boiler beefy',
#   'boiler beek',
#   'boiler beel',
#   'boiler bee',
#   'boiler beefs',
#   'boiler bees',
#   'boiler beaf',
#   'boiler beet',
#   'boiler beez',
#   'boiler beefl',
#   'boiler beep',
#   'boiler peef',
#   'boiler beed',
#   'boiler geef',
#   'boiler beeef',
#   'boiler beeff',
#   'boiler beer',
#   'boiler beeg',
#   'boiler boef',
#   'boiler beff',
#   'boiler teef',
#   'boiler beef',
#   'broiled eef',
#   'broiled deef',
#   'broiled reef',
#   'broiled bef',
#   'broiled beefy',
#   'broiled beek',
#   'broiled beel',
#   'broiled bee',
#   'broiled beefs',
#   'broiled bees',
#   'broiled beaf',
#   'broiled beet',
#   'broiled beez',
#   'broiled beefl',
#   'broiled beep',
#   'broiled peef',
#   'broiled beed',
#   'broiled geef',
#   'broiled beeef',
#   'broiled beeff',
#   'broiled beer',
#   'broiled beeg',
#   'broiled boef',
#   'broiled beff',
#   'broiled teef',
#   'broiled beef',
#   'loiled eef',
#   'loiled deef',
#   'loiled reef',
#   'loiled bef',
#   'loiled beefy',
#   'loiled beek',
#   'loiled beel',
#   'loiled bee',
#   'loiled beefs',
#   'loiled bees',
#   'loiled beaf',
#   'loiled beet',
#   'loiled beez',
#   'loiled beefl',
#   'loiled beep',
#   'loiled peef',
#   'loiled beed',
#   'loiled geef',
#   'loiled beeef',
#   'loiled beeff',
#   'loiled beer',
#   'loiled beeg',
#   'loiled boef',
#   'loiled beff',
#   'loiled teef',
#   'loiled beef',
#   'bowled eef',
#   'bowled deef',
#   'bowled reef',
#   'bowled bef',
#   'bowled beefy',
#   'bowled beek',
#   'bowled beel',
#   'bowled bee',
#   'bowled beefs',
#   'bowled bees',
#   'bowled beaf',
#   'bowled beet',
#   'bowled beez',
#   'bowled beefl',
#   'bowled beep',
#   'bowled peef',
#   'bowled beed',
#   'bowled geef',
#   'bowled beeef',
#   'bowled beeff',
#   'bowled beer',
#   'bowled beeg',
#   'bowled boef',
#   'bowled beff',
#   'bowled teef',
#   'bowled beef',
#   'oiled eef',
#   'oiled deef',
#   'oiled reef',
#   'oiled bef',
#   'oiled beefy',
#   'oiled beek',
#   'oiled beel',
#   'oiled bee',
#   'oiled beefs',
#   'oiled bees',
#   'oiled beaf',
#   'oiled beet',
#   'oiled beez',
#   'oiled beefl',
#   'oiled beep',
#   'oiled peef',
#   'oiled beed',
#   'oiled geef',
#   'oiled beeef',
#   'oiled beeff',
#   'oiled beer',
#   'oiled beeg',
#   'oiled boef',
#   'oiled beff',
#   'oiled teef',
#   'oiled beef',
#   'boyled eef',
#   'boyled deef',
#   'boyled reef',
#   'boyled bef',
#   'boyled beefy',
#   'boyled beek',
#   'boyled beel',
#   'boyled bee',
#   'boyled beefs',
#   'boyled bees',
#   'boyled beaf',
#   'boyled beet',
#   'boyled beez',
#   'boyled beefl',
#   'boyled beep',
#   'boyled peef',
#   'boyled beed',
#   'boyled geef',
#   'boyled beeef',
#   'boyled beeff',
#   'boyled beer',
#   'boyled beeg',
#   'boyled boef',
#   'boyled beff',
#   'boyled teef',
#   'boyled beef',
#   'toiled eef',
#   'toiled deef',
#   'toiled reef',
#   'toiled bef',
#   'toiled beefy',
#   'toiled beek',
#   'toiled beel',
#   'toiled bee',
#   'toiled beefs',
#   'toiled bees',
#   'toiled beaf',
#   'toiled beet',
#   'toiled beez',
#   'toiled beefl',
#   'toiled beep',
#   'toiled peef',
#   'toiled beed',
#   'toiled geef',
#   'toiled beeef',
#   'toiled beeff',
#   'toiled beer',
#   'toiled beeg',
#   'toiled boef',
#   'toiled beff',
#   'toiled teef',
#   'toiled beef',
#   'foiled eef',
#   'foiled deef',
#   'foiled reef',
#   'foiled bef',
#   'foiled beefy',
#   'foiled beek',
#   'foiled beel',
#   'foiled bee',
#   'foiled beefs',
#   'foiled bees',
#   'foiled beaf',
#   'foiled beet',
#   'foiled beez',
#   'foiled beefl',
#   'foiled beep',
#   'foiled peef',
#   'foiled beed',
#   'foiled geef',
#   'foiled beeef',
#   'foiled beeff',
#   'foiled beer',
#   'foiled beeg',
#   'foiled boef',
#   'foiled beff',
#   'foiled teef',
#   'foiled beef',
#   'bouled eef',
#   'bouled deef',
#   'bouled reef',
#   'bouled bef',
#   'bouled beefy',
#   'bouled beek',
#   'bouled beel',
#   'bouled bee',
#   'bouled beefs',
#   'bouled bees',
#   'bouled beaf',
#   'bouled beet',
#   'bouled beez',
#   'bouled beefl',
#   'bouled beep',
#   'bouled peef',
#   'bouled beed',
#   'bouled geef',
#   'bouled beeef',
#   'bouled beeff',
#   'bouled beer',
#   'bouled beeg',
#   'bouled boef',
#   'bouled beff',
#   'bouled teef',
#   'bouled beef',
#   'boile eef',
#   'boile deef',
#   'boile reef',
#   'boile bef',
#   'boile beefy',
#   'boile beek',
#   'boile beel',
#   'boile bee',
#   'boile beefs',
#   'boile bees',
#   'boile beaf',
#   'boile beet',
#   'boile beez',
#   'boile beefl',
#   'boile beep',
#   'boile peef',
#   'boile beed',
#   'boile geef',
#   'boile beeef',
#   'boile beeff',
#   'boile beer',
#   'boile beeg',
#   'boile boef',
#   'boile beff',
#   'boile teef',
#   'boile beef',
#   'bolied eef',
#   'bolied deef',
#   'bolied reef',
#   'bolied bef',
#   'bolied beefy',
#   'bolied beek',
#   'bolied beel',
#   'bolied bee',
#   'bolied beefs',
#   'bolied bees',
#   'bolied beaf',
#   'bolied beet',
#   'bolied beez',
#   'bolied beefl',
#   'bolied beep',
#   'bolied peef',
#   'bolied beed',
#   'bolied geef',
#   'bolied beeef',
#   'bolied beeff',
#   'bolied beer',
#   'bolied beeg',
#   'bolied boef',
#   'bolied beff',
#   'bolied teef',
#   'bolied beef',
#   'coiled eef',
#   'coiled deef',
#   'coiled reef',
#   'coiled bef',
#   'coiled beefy',
#   'coiled beek',
#   'coiled beel',
#   'coiled bee',
#   'coiled beefs',
#   'coiled bees',
#   'coiled beaf',
#   'coiled beet',
#   'coiled beez',
#   'coiled beefl',
#   'coiled beep',
#   'coiled peef',
#   'coiled beed',
#   'coiled geef',
#   'coiled beeef',
#   'coiled beeff',
#   'coiled beer',
#   'coiled beeg',
#   'coiled boef',
#   'coiled beff',
#   'coiled teef',
#   'coiled beef',
#   'boiles eef',
#   'boiles deef',
#   'boiles reef',
#   'boiles bef',
#   'boiles beefy',
#   'boiles beek',
#   'boiles beel',
#   'boiles bee',
#   'boiles beefs',
#   'boiles bees',
#   'boiles beaf',
#   'boiles beet',
#   'boiles beez',
#   'boiles beefl',
#   'boiles beep',
#   'boiles peef',
#   'boiles beed',
#   'boiles geef',
#   'boiles beeef',
#   'boiles beeff',
#   'boiles beer',
#   'boiles beeg',
#   'boiles boef',
#   'boiles beff',
#   'boiles teef',
#   'boiles beef',
#   'boild eef',
#   'boild deef',
#   'boild reef',
#   'boild bef',
#   'boild beefy',
#   'boild beek',
#   'boild beel',
#   'boild bee',
#   'boild beefs',
#   'boild bees',
#   'boild beaf',
#   'boild beet',
#   'boild beez',
#   'boild beefl',
#   'boild beep',
#   'boild peef',
#   'boild beed',
#   'boild geef',
#   'boild beeef',
#   'boild beeff',
#   'boild beer',
#   'boild beeg',
#   'boild boef',
#   'boild beff',
#   'boild teef',
#   'boild beef',
#   'soiled eef',
#   'soiled deef',
#   'soiled reef',
#   'soiled bef',
#   'soiled beefy',
#   'soiled beek',
#   'soiled beel',
#   'soiled bee',
#   'soiled beefs',
#   'soiled bees',
#   'soiled beaf',
#   'soiled beet',
#   'soiled beez',
#   'soiled beefl',
#   'soiled beep',
#   'soiled peef',
#   'soiled beed',
#   'soiled geef',
#   'soiled beeef',
#   'soiled beeff',
#   'soiled beer',
#   'soiled beeg',
#   'soiled boef',
#   'soiled beff',
#   'soiled teef',
#   'soiled beef',
#   'boilet eef',
#   'boilet deef',
#   'boilet reef',
#   'boilet bef',
#   'boilet beefy',
#   'boilet beek',
#   'boilet beel',
#   'boilet bee',
#   'boilet beefs',
#   'boilet bees',
#   'boilet beaf',
#   'boilet beet',
#   'boilet beez',
#   'boilet beefl',
#   'boilet beep',
#   'boilet peef',
#   'boilet beed',
#   'boilet geef',
#   'boilet beeef',
#   'boilet beeff',
#   'boilet beer',
#   'boilet beeg',
#   'boilet boef',
#   'boilet beff',
#   'boilet teef',
#   'boilet beef',
#   'boled eef',
#   'boled deef',
#   'boled reef',
#   'boled bef',
#   'boled beefy',
#   'boled beek',
#   'boled beel',
#   'boled bee',
#   'boled beefs',
#   'boled bees',
#   'boled beaf',
#   'boled beet',
#   'boled beez',
#   'boled beefl',
#   'boled beep',
#   'boled peef',
#   'boled beed',
#   'boled geef',
#   'boled beeef',
#   'boled beeff',
#   'boled beer',
#   'boled beeg',
#   'boled boef',
#   'boled beff',
#   'boled teef',
#   'boled beef',
#   'boiled eef',
#   'boiled deef',
#   'boiled reef',
#   'boiled bef',
#   'boiled beefy',
#   'boiled beek',
#   'boiled beel',
#   'boiled bee',
#   'boiled beefs',
#   'boiled bees',
#   'boiled beaf',
#   'boiled beet',
#   'boiled beez',
#   'boiled beefl',
#   'boiled beep',
#   'boiled peef',
#   'boiled beed',
#   'boiled geef',
#   'boiled beeef',
#   'boiled beeff',
#   'boiled beer',
#   'boiled beeg',
#   'boiled boef',
#   'boiled beff',
#   'boiled teef',
#   'boiled beef',
#   'boiler eef',
#   'boiler deef',
#   'boiler reef',
#   'boiler bef',
#   'boiler beefy',
#   'boiler beek',
#   'boiler beel',
#   'boiler bee',
#   'boiler beefs',
#   'boiler bees',
#   'boiler beaf',
#   'boiler beet',
#   'boiler beez',
#   'boiler beefl',
#   'boiler beep',
#   'boiler peef',
#   'boiler beed',
#   'boiler geef',
#   'boiler beeef',
#   'boiler beeff',
#   'boiler beer',
#   'boiler beeg',
#   'boiler boef',
#   'boiler beff',
#   'boiler teef',
#   'boiler beef',
#   'broiled eef',
#   'broiled deef',
#   'broiled reef',
#   'broiled bef',
#   'broiled beefy',
#   'broiled beek',
#   'broiled beel',
#   'broiled bee',
#   'broiled beefs',
#   'broiled bees',
#   'broiled beaf',
#   'broiled beet',
#   'broiled beez',
#   'broiled beefl',
#   'broiled beep',
#   'broiled peef',
#   'broiled beed',
#   'broiled geef',
#   'broiled beeef',
#   'broiled beeff',
#   'broiled beer',
#   'broiled beeg',
#   'broiled boef',
#   'broiled beff',
#   'broiled teef',
#   'broiled beef',
#   'loiled eef',
#   'loiled deef',
#   'loiled reef',
#   'loiled bef',
#   'loiled beefy',
#   'loiled beek',
#   'loiled beel',
#   'loiled bee',
#   'loiled beefs',
#   'loiled bees',
#   'loiled beaf',
#   'loiled beet',
#   ...],
#  ['eef wellington',
#   'deef wellington',
#   'reef wellington',
#   'bef wellington',
#   'beefy wellington',
#   'beek wellington',
#   'beel wellington',
#   'bee wellington',
#   'beefs wellington',
#   'bees wellington',
#   'beaf wellington',
#   'beet wellington',
#   'beez wellington',
#   'beefl wellington',
#   'beep wellington',
#   'peef wellington',
#   'beed wellington',
#   'geef wellington',
#   'beeef wellington',
#   'beeff wellington',
#   'beer wellington',
#   'beeg wellington',
#   'boef wellington',
#   'beff wellington',
#   'teef wellington',
#   'beef wellington',
#   'eef wellington',
#   'deef wellington',
#   'reef wellington',
#   'bef wellington',
#   'beefy wellington',
#   'beek wellington',
#   'beel wellington',
#   'bee wellington',
#   'beefs wellington',
#   'bees wellington',
#   'beaf wellington',
#   'beet wellington',
#   'beez wellington',
#   'beefl wellington',
#   'beep wellington',
#   'peef wellington',
#   'beed wellington',
#   'geef wellington',
#   'beeef wellington',
#   'beeff wellington',
#   'beer wellington',
#   'beeg wellington',
#   'boef wellington',
#   'beff wellington',
#   'teef wellington',
#   'beef wellington',
#   'eef wellington',
#   'deef wellington',
#   'reef wellington',
#   'bef wellington',
#   'beefy wellington',
#   'beek wellington',
#   'beel wellington',
#   'bee wellington',
#   'beefs wellington',
#   'bees wellington',
#   'beaf wellington',
#   'beet wellington',
#   'beez wellington',
#   'beefl wellington',
#   'beep wellington',
#   'peef wellington',
#   'beed wellington',
#   'geef wellington',
#   'beeef wellington',
#   'beeff wellington',
#   'beer wellington',
#   'beeg wellington',
#   'boef wellington',
#   'beff wellington',
#   'teef wellington',
#   'beef wellington',
#   'eef wellington',
#   'deef wellington',
#   'reef wellington',
#   'bef wellington',
#   'beefy wellington',
#   'beek wellington',
#   'beel wellington',
#   'bee wellington',
#   'beefs wellington',
#   'bees wellington',
#   'beaf wellington',
#   'beet wellington',
#   'beez wellington',
#   'beefl wellington',
#   'beep wellington',
#   'peef wellington',
#   'beed wellington',
#   'geef wellington',
#   'beeef wellington',
#   'beeff wellington',
#   'beer wellington',
#   'beeg wellington',
#   'boef wellington',
#   'beff wellington',
#   'teef wellington',
#   'beef wellington',
#   'eef wellington',
#   'deef wellington',
#   'reef wellington',
#   'bef wellington',
#   'beefy wellington',
#   'beek wellington',
#   'beel wellington',
#   'bee wellington',
#   'beefs wellington',
#   'bees wellington',
#   'beaf wellington',
#   'beet wellington',
#   'beez wellington',
#   'beefl wellington',
#   'beep wellington',
#   'peef wellington',
#   'beed wellington',
#   'geef wellington',
#   'beeef wellington',
#   'beeff wellington',
#   'beer wellington',
#   'beeg wellington',
#   'boef wellington',
#   'beff wellington',
#   'teef wellington',
#   'beef wellington',
#   'eef wellington',
#   'deef wellington',
#   'reef wellington',
#   'bef wellington',
#   'beefy wellington',
#   'beek wellington',
#   'beel wellington',
#   'bee wellington',
#   'beefs wellington',
#   'bees wellington',
#   'beaf wellington',
#   'beet wellington',
#   'beez wellington',
#   'beefl wellington',
#   'beep wellington',
#   'peef wellington',
#   'beed wellington',
#   'geef wellington',
#   'beeef wellington',
#   'beeff wellington',
#   'beer wellington',
#   'beeg wellington',
#   'boef wellington',
#   'beff wellington',
#   'teef wellington',
#   'beef wellington',
#   'eef wellington',
#   'deef wellington',
#   'reef wellington',
#   'bef wellington',
#   'beefy wellington',
#   'beek wellington',
#   'beel wellington',
#   'bee wellington',
#   'beefs wellington',
#   'bees wellington',
#   'beaf wellington',
#   'beet wellington',
#   'beez wellington',
#   'beefl wellington',
#   'beep wellington',
#   'peef wellington',
#   'beed wellington',
#   'geef wellington',
#   'beeef wellington',
#   'beeff wellington',
#   'beer wellington',
#   'beeg wellington',
#   'boef wellington',
#   'beff wellington',
#   'teef wellington',
#   'beef wellington',
#   'eef wellington',
#   'deef wellington',
#   'reef wellington',
#   'bef wellington',
#   'beefy wellington',
#   'beek wellington',
#   'beel wellington',
#   'bee wellington',
#   'beefs wellington',
#   'bees wellington',
#   'beaf wellington',
#   'beet wellington',
#   'beez wellington',
#   'beefl wellington',
#   'beep wellington',
#   'peef wellington',
#   'beed wellington',
#   'geef wellington',
#   'beeef wellington',
#   'beeff wellington',
#   'beer wellington',
#   'beeg wellington',
#   'boef wellington',
#   'beff wellington',
#   'teef wellington',
#   'beef wellington',
#   'eef wellington',
#   'deef wellington',
#   'reef wellington',
#   'bef wellington',
#   'beefy wellington',
#   'beek wellington',
#   'beel wellington',
#   'bee wellington',
#   'beefs wellington',
#   'bees wellington',
#   'beaf wellington',
#   'beet wellington',
#   'beez wellington',
#   'beefl wellington',
#   'beep wellington',
#   'peef wellington',
#   'beed wellington',
#   'geef wellington',
#   'beeef wellington',
#   'beeff wellington',
#   'beer wellington',
#   'beeg wellington',
#   'boef wellington',
#   'beff wellington',
#   'teef wellington',
#   'beef wellington',
#   'eef wellington',
#   'deef wellington',
#   'reef wellington',
#   'bef wellington',
#   'beefy wellington',
#   'beek wellington',
#   'beel wellington',
#   'bee wellington',
#   'beefs wellington',
#   'bees wellington',
#   'beaf wellington',
#   'beet wellington',
#   'beez wellington',
#   'beefl wellington',
#   'beep wellington',
#   'peef wellington',
#   'beed wellington',
#   'geef wellington',
#   'beeef wellington',
#   'beeff wellington',
#   'beer wellington',
#   'beeg wellington',
#   'boef wellington',
#   'beff wellington',
#   'teef wellington',
#   'beef wellington',
#   'eef wellington',
#   'deef wellington',
#   'reef wellington',
#   'bef wellington',
#   'beefy wellington',
#   'beek wellington',
#   'beel wellington',
#   'bee wellington',
#   'beefs wellington',
#   'bees wellington',
#   'beaf wellington',
#   'beet wellington',
#   'beez wellington',
#   'beefl wellington',
#   'beep wellington',
#   'peef wellington',
#   'beed wellington',
#   'geef wellington',
#   'beeef wellington',
#   'beeff wellington',
#   'beer wellington',
#   'beeg wellington',
#   'boef wellington',
#   'beff wellington',
#   'teef wellington',
#   'beef wellington',
#   'eef wellington',
#   'deef wellington',
#   'reef wellington',
#   'bef wellington',
#   'beefy wellington',
#   'beek wellington',
#   'beel wellington',
#   'bee wellington',
#   'beefs wellington',
#   'bees wellington',
#   'beaf wellington',
#   'beet wellington',
#   'beez wellington',
#   'beefl wellington',
#   'beep wellington',
#   'peef wellington',
#   'beed wellington',
#   'geef wellington',
#   'beeef wellington',
#   'beeff wellington',
#   'beer wellington',
#   'beeg wellington',
#   'boef wellington',
#   'beff wellington',
#   'teef wellington',
#   'beef wellington',
#   'eef wellington',
#   'deef wellington',
#   'reef wellington',
#   'bef wellington',
#   'beefy wellington',
#   'beek wellington',
#   'beel wellington',
#   'bee wellington',
#   'beefs wellington',
#   'bees wellington',
#   'beaf wellington',
#   'beet wellington',
#   'beez wellington',
#   'beefl wellington',
#   'beep wellington',
#   'peef wellington',
#   'beed wellington',
#   'geef wellington',
#   'beeef wellington',
#   'beeff wellington',
#   'beer wellington',
#   'beeg wellington',
#   'boef wellington',
#   'beff wellington',
#   'teef wellington',
#   'beef wellington',
#   'eef wellington',
#   'deef wellington',
#   'reef wellington',
#   'bef wellington',
#   'beefy wellington',
#   'beek wellington',
#   'beel wellington',
#   'bee wellington',
#   'beefs wellington',
#   'bees wellington',
#   'beaf wellington',
#   'beet wellington',
#   'beez wellington',
#   'beefl wellington',
#   'beep wellington',
#   'peef wellington',
#   'beed wellington',
#   'geef wellington',
#   'beeef wellington',
#   'beeff wellington',
#   'beer wellington',
#   'beeg wellington',
#   'boef wellington',
#   'beff wellington',
#   'teef wellington',
#   'beef wellington',
#   'eef wellington',
#   'deef wellington',
#   'reef wellington',
#   'bef wellington',
#   'beefy wellington',
#   'beek wellington',
#   'beel wellington',
#   'bee wellington',
#   'beefs wellington',
#   'bees wellington',
#   'beaf wellington',
#   'beet wellington',
#   'beez wellington',
#   'beefl wellington',
#   'beep wellington',
#   'peef wellington',
#   'beed wellington',
#   'geef wellington',
#   'beeef wellington',
#   'beeff wellington',
#   'beer wellington',
#   'beeg wellington',
#   'boef wellington',
#   'beff wellington',
#   'teef wellington',
#   'beef wellington',
#   'eef wellington',
#   'deef wellington',
#   'reef wellington',
#   'bef wellington',
#   'beefy wellington',
#   'beek wellington',
#   'beel wellington',
#   'bee wellington',
#   'beefs wellington',
#   'bees wellington',
#   'beaf wellington',
#   'beet wellington',
#   'beez wellington',
#   'beefl wellington',
#   'beep wellington',
#   'peef wellington',
#   'beed wellington',
#   'geef wellington',
#   'beeef wellington',
#   'beeff wellington',
#   'beer wellington',
#   'beeg wellington',
#   'boef wellington',
#   'beff wellington',
#   'teef wellington',
#   'beef wellington',
#   'eef wellington',
#   'deef wellington',
#   'reef wellington',
#   'bef wellington',
#   'beefy wellington',
#   'beek wellington',
#   'beel wellington',
#   'bee wellington',
#   'beefs wellington',
#   'bees wellington',
#   'beaf wellington',
#   'beet wellington',
#   'beez wellington',
#   'beefl wellington',
#   'beep wellington',
#   'peef wellington',
#   'beed wellington',
#   'geef wellington',
#   'beeef wellington',
#   'beeff wellington',
#   'beer wellington',
#   'beeg wellington',
#   'boef wellington',
#   'beff wellington',
#   'teef wellington',
#   'beef wellington',
#   'eef wellington',
#   'deef wellington',
#   'reef wellington',
#   'bef wellington',
#   'beefy wellington',
#   'beek wellington',
#   'beel wellington',
#   'bee wellington',
#   'beefs wellington',
#   'bees wellington',
#   'beaf wellington',
#   'beet wellington',
#   'beez wellington',
#   'beefl wellington',
#   'beep wellington',
#   'peef wellington',
#   'beed wellington',
#   'geef wellington',
#   'beeef wellington',
#   'beeff wellington',
#   'beer wellington',
#   'beeg wellington',
#   'boef wellington',
#   'beff wellington',
#   'teef wellington',
#   'beef wellington',
#   'eef wellinton',
#   'deef wellinton',
#   'reef wellinton',
#   'bef wellinton',
#   'beefy wellinton',
#   'beek wellinton',
#   'beel wellinton',
#   'bee wellinton',
#   'beefs wellinton',
#   'bees wellinton',
#   'beaf wellinton',
#   'beet wellinton',
#   'beez wellinton',
#   'beefl wellinton',
#   'beep wellinton',
#   'peef wellinton',
#   'beed wellinton',
#   'geef wellinton',
#   'beeef wellinton',
#   'beeff wellinton',
#   'beer wellinton',
#   'beeg wellinton',
#   'boef wellinton',
#   'beff wellinton',
#   'teef wellinton',
#   'beef wellinton',
#   'eef wellinton',
#   'deef wellinton',
#   'reef wellinton',
#   'bef wellinton',
#   'beefy wellinton',
#   'beek wellinton',
#   'beel wellinton',
#   'bee wellinton',
#   'beefs wellinton',
#   'bees wellinton',
#   'beaf wellinton',
#   'beet wellinton',
#   'beez wellinton',
#   'beefl wellinton',
#   'beep wellinton',
#   'peef wellinton',
#   'beed wellinton',
#   'geef wellinton',
#   'beeef wellinton',
#   'beeff wellinton',
#   'beer wellinton',
#   'beeg wellinton',
#   'boef wellinton',
#   'beff wellinton',
#   'teef wellinton',
#   'beef wellinton',
#   'eef wellinton',
#   'deef wellinton',
#   'reef wellinton',
#   'bef wellinton',
#   'beefy wellinton',
#   'beek wellinton',
#   'beel wellinton',
#   'bee wellinton',
#   'beefs wellinton',
#   'bees wellinton',
#   'beaf wellinton',
#   'beet wellinton',
#   'beez wellinton',
#   'beefl wellinton',
#   'beep wellinton',
#   'peef wellinton',
#   'beed wellinton',
#   'geef wellinton',
#   'beeef wellinton',
#   'beeff wellinton',
#   'beer wellinton',
#   'beeg wellinton',
#   'boef wellinton',
#   'beff wellinton',
#   'teef wellinton',
#   'beef wellinton',
#   'eef wellinton',
#   'deef wellinton',
#   'reef wellinton',
#   'bef wellinton',
#   'beefy wellinton',
#   'beek wellinton',
#   'beel wellinton',
#   'bee wellinton',
#   'beefs wellinton',
#   'bees wellinton',
#   'beaf wellinton',
#   'beet wellinton',
#   'beez wellinton',
#   'beefl wellinton',
#   'beep wellinton',
#   'peef wellinton',
#   'beed wellinton',
#   'geef wellinton',
#   'beeef wellinton',
#   'beeff wellinton',
#   'beer wellinton',
#   'beeg wellinton',
#   'boef wellinton',
#   'beff wellinton',
#   'teef wellinton',
#   'beef wellinton',
#   'eef wellinton',
#   'deef wellinton',
#   'reef wellinton',
#   'bef wellinton',
#   'beefy wellinton',
#   'beek wellinton',
#   'beel wellinton',
#   'bee wellinton',
#   'beefs wellinton',
#   'bees wellinton',
#   'beaf wellinton',
#   'beet wellinton',
#   'beez wellinton',
#   'beefl wellinton',
#   'beep wellinton',
#   'peef wellinton',
#   'beed wellinton',
#   'geef wellinton',
#   'beeef wellinton',
#   'beeff wellinton',
#   'beer wellinton',
#   'beeg wellinton',
#   'boef wellinton',
#   'beff wellinton',
#   'teef wellinton',
#   'beef wellinton',
#   'eef wellinton',
#   'deef wellinton',
#   'reef wellinton',
#   'bef wellinton',
#   'beefy wellinton',
#   'beek wellinton',
#   'beel wellinton',
#   'bee wellinton',
#   'beefs wellinton',
#   'bees wellinton',
#   'beaf wellinton',
#   'beet wellinton',
#   'beez wellinton',
#   'beefl wellinton',
#   'beep wellinton',
#   'peef wellinton',
#   'beed wellinton',
#   'geef wellinton',
#   'beeef wellinton',
#   'beeff wellinton',
#   'beer wellinton',
#   'beeg wellinton',
#   'boef wellinton',
#   'beff wellinton',
#   'teef wellinton',
#   'beef wellinton',
#   'eef wellinton',
#   'deef wellinton',
#   'reef wellinton',
#   'bef wellinton',
#   'beefy wellinton',
#   'beek wellinton',
#   'beel wellinton',
#   'bee wellinton',
#   'beefs wellinton',
#   'bees wellinton',
#   'beaf wellinton',
#   'beet wellinton',
#   'beez wellinton',
#   'beefl wellinton',
#   'beep wellinton',
#   'peef wellinton',
#   'beed wellinton',
#   'geef wellinton',
#   'beeef wellinton',
#   'beeff wellinton',
#   'beer wellinton',
#   'beeg wellinton',
#   'boef wellinton',
#   'beff wellinton',
#   'teef wellinton',
#   'beef wellinton',
#   'eef wellinton',
#   'deef wellinton',
#   'reef wellinton',
#   'bef wellinton',
#   'beefy wellinton',
#   'beek wellinton',
#   'beel wellinton',
#   'bee wellinton',
#   'beefs wellinton',
#   'bees wellinton',
#   'beaf wellinton',
#   'beet wellinton',
#   'beez wellinton',
#   'beefl wellinton',
#   'beep wellinton',
#   'peef wellinton',
#   'beed wellinton',
#   'geef wellinton',
#   'beeef wellinton',
#   'beeff wellinton',
#   'beer wellinton',
#   'beeg wellinton',
#   'boef wellinton',
#   'beff wellinton',
#   'teef wellinton',
#   'beef wellinton',
#   'eef wellinton',
#   'deef wellinton',
#   'reef wellinton',
#   'bef wellinton',
#   'beefy wellinton',
#   'beek wellinton',
#   'beel wellinton',
#   'bee wellinton',
#   'beefs wellinton',
#   'bees wellinton',
#   'beaf wellinton',
#   'beet wellinton',
#   'beez wellinton',
#   'beefl wellinton',
#   'beep wellinton',
#   'peef wellinton',
#   'beed wellinton',
#   'geef wellinton',
#   'beeef wellinton',
#   'beeff wellinton',
#   'beer wellinton',
#   'beeg wellinton',
#   'boef wellinton',
#   'beff wellinton',
#   'teef wellinton',
#   'beef wellinton',
#   'eef wellinton',
#   'deef wellinton',
#   'reef wellinton',
#   'bef wellinton',
#   'beefy wellinton',
#   'beek wellinton',
#   'beel wellinton',
#   'bee wellinton',
#   'beefs wellinton',
#   'bees wellinton',
#   'beaf wellinton',
#   'beet wellinton',
#   'beez wellinton',
#   'beefl wellinton',
#   'beep wellinton',
#   'peef wellinton',
#   'beed wellinton',
#   'geef wellinton',
#   'beeef wellinton',
#   'beeff wellinton',
#   'beer wellinton',
#   'beeg wellinton',
#   'boef wellinton',
#   'beff wellinton',
#   'teef wellinton',
#   'beef wellinton',
#   'eef wellinton',
#   'deef wellinton',
#   'reef wellinton',
#   'bef wellinton',
#   'beefy wellinton',
#   'beek wellinton',
#   'beel wellinton',
#   'bee wellinton',
#   'beefs wellinton',
#   'bees wellinton',
#   'beaf wellinton',
#   'beet wellinton',
#   'beez wellinton',
#   'beefl wellinton',
#   'beep wellinton',
#   'peef wellinton',
#   'beed wellinton',
#   'geef wellinton',
#   'beeef wellinton',
#   'beeff wellinton',
#   'beer wellinton',
#   'beeg wellinton',
#   'boef wellinton',
#   'beff wellinton',
#   'teef wellinton',
#   'beef wellinton',
#   'eef wellinton',
#   'deef wellinton',
#   'reef wellinton',
#   'bef wellinton',
#   'beefy wellinton',
#   'beek wellinton',
#   'beel wellinton',
#   'bee wellinton',
#   'beefs wellinton',
#   'bees wellinton',
#   'beaf wellinton',
#   'beet wellinton',
#   'beez wellinton',
#   'beefl wellinton',
#   'beep wellinton',
#   'peef wellinton',
#   'beed wellinton',
#   'geef wellinton',
#   'beeef wellinton',
#   'beeff wellinton',
#   'beer wellinton',
#   'beeg wellinton',
#   'boef wellinton',
#   'beff wellinton',
#   'teef wellinton',
#   'beef wellinton',
#   'eef wellinton',
#   'deef wellinton',
#   'reef wellinton',
#   'bef wellinton',
#   'beefy wellinton',
#   'beek wellinton',
#   'beel wellinton',
#   'bee wellinton',
#   'beefs wellinton',
#   'bees wellinton',
#   'beaf wellinton',
#   'beet wellinton',
#   'beez wellinton',
#   'beefl wellinton',
#   'beep wellinton',
#   'peef wellinton',
#   'beed wellinton',
#   'geef wellinton',
#   'beeef wellinton',
#   'beeff wellinton',
#   'beer wellinton',
#   'beeg wellinton',
#   'boef wellinton',
#   'beff wellinton',
#   'teef wellinton',
#   'beef wellinton',
#   'eef wellinton',
#   'deef wellinton',
#   'reef wellinton',
#   'bef wellinton',
#   'beefy wellinton',
#   'beek wellinton',
#   'beel wellinton',
#   'bee wellinton',
#   'beefs wellinton',
#   'bees wellinton',
#   'beaf wellinton',
#   'beet wellinton',
#   'beez wellinton',
#   'beefl wellinton',
#   'beep wellinton',
#   'peef wellinton',
#   'beed wellinton',
#   'geef wellinton',
#   'beeef wellinton',
#   'beeff wellinton',
#   'beer wellinton',
#   'beeg wellinton',
#   'boef wellinton',
#   'beff wellinton',
#   'teef wellinton',
#   'beef wellinton',
#   'eef wellinton',
#   'deef wellinton',
#   'reef wellinton',
#   'bef wellinton',
#   'beefy wellinton',
#   'beek wellinton',
#   'beel wellinton',
#   'bee wellinton',
#   'beefs wellinton',
#   'bees wellinton',
#   'beaf wellinton',
#   'beet wellinton',
#   'beez wellinton',
#   'beefl wellinton',
#   'beep wellinton',
#   'peef wellinton',
#   'beed wellinton',
#   'geef wellinton',
#   'beeef wellinton',
#   'beeff wellinton',
#   'beer wellinton',
#   'beeg wellinton',
#   'boef wellinton',
#   'beff wellinton',
#   'teef wellinton',
#   'beef wellinton',
#   'eef wellinton',
#   'deef wellinton',
#   'reef wellinton',
#   'bef wellinton',
#   'beefy wellinton',
#   'beek wellinton',
#   'beel wellinton',
#   'bee wellinton',
#   'beefs wellinton',
#   'bees wellinton',
#   'beaf wellinton',
#   'beet wellinton',
#   'beez wellinton',
#   'beefl wellinton',
#   'beep wellinton',
#   'peef wellinton',
#   'beed wellinton',
#   'geef wellinton',
#   'beeef wellinton',
#   'beeff wellinton',
#   'beer wellinton',
#   'beeg wellinton',
#   'boef wellinton',
#   'beff wellinton',
#   'teef wellinton',
#   'beef wellinton',
#   'eef wellinton',
#   'deef wellinton',
#   'reef wellinton',
#   'bef wellinton',
#   'beefy wellinton',
#   'beek wellinton',
#   'beel wellinton',
#   'bee wellinton',
#   'beefs wellinton',
#   'bees wellinton',
#   'beaf wellinton',
#   'beet wellinton',
#   'beez wellinton',
#   'beefl wellinton',
#   'beep wellinton',
#   'peef wellinton',
#   'beed wellinton',
#   'geef wellinton',
#   'beeef wellinton',
#   'beeff wellinton',
#   'beer wellinton',
#   'beeg wellinton',
#   'boef wellinton',
#   'beff wellinton',
#   'teef wellinton',
#   'beef wellinton',
#   'eef wellinton',
#   'deef wellinton',
#   'reef wellinton',
#   'bef wellinton',
#   'beefy wellinton',
#   'beek wellinton',
#   'beel wellinton',
#   'bee wellinton',
#   'beefs wellinton',
#   'bees wellinton',
#   'beaf wellinton',
#   'beet wellinton',
#   'beez wellinton',
#   'beefl wellinton',
#   'beep wellinton',
#   'peef wellinton',
#   'beed wellinton',
#   'geef wellinton',
#   'beeef wellinton',
#   'beeff wellinton',
#   'beer wellinton',
#   'beeg wellinton',
#   'boef wellinton',
#   'beff wellinton',
#   'teef wellinton',
#   'beef wellinton',
#   'eef wellingon',
#   'deef wellingon',
#   'reef wellingon',
#   'bef wellingon',
#   'beefy wellingon',
#   'beek wellingon',
#   'beel wellingon',
#   'bee wellingon',
#   'beefs wellingon',
#   'bees wellingon',
#   'beaf wellingon',
#   'beet wellingon',
#   'beez wellingon',
#   'beefl wellingon',
#   'beep wellingon',
#   'peef wellingon',
#   'beed wellingon',
#   'geef wellingon',
#   'beeef wellingon',
#   'beeff wellingon',
#   'beer wellingon',
#   'beeg wellingon',
#   'boef wellingon',
#   'beff wellingon',
#   'teef wellingon',
#   'beef wellingon',
#   'eef wellingon',
#   'deef wellingon',
#   'reef wellingon',
#   'bef wellingon',
#   'beefy wellingon',
#   'beek wellingon',
#   'beel wellingon',
#   'bee wellingon',
#   'beefs wellingon',
#   'bees wellingon',
#   'beaf wellingon',
#   'beet wellingon',
#   'beez wellingon',
#   'beefl wellingon',
#   'beep wellingon',
#   'peef wellingon',
#   'beed wellingon',
#   'geef wellingon',
#   'beeef wellingon',
#   'beeff wellingon',
#   'beer wellingon',
#   'beeg wellingon',
#   'boef wellingon',
#   'beff wellingon',
#   'teef wellingon',
#   'beef wellingon',
#   'eef wellingon',
#   'deef wellingon',
#   'reef wellingon',
#   'bef wellingon',
#   'beefy wellingon',
#   'beek wellingon',
#   'beel wellingon',
#   'bee wellingon',
#   'beefs wellingon',
#   'bees wellingon',
#   'beaf wellingon',
#   'beet wellingon',
#   ...]]

# %%
word = "boiled bef wellingon"

query = [[candidate[0] for candidate in get_candidates(term, iula_freq_len_mapping)] + [term] for term in word.split()]
combinations = np.array(np.meshgrid(*query)).T.reshape(-1,len(word.split()))
combinations
joined_combis = [" ".join(combi) for combi in combinations]
joined_combis
# Out:
# ['boiler bof wellington',
#  'boiler bnf wellington',
#  'boiler bet wellington',
#  'boiler bel wellington',
#  'boiler bed wellington',
#  'boiler ref wellington',
#  'boiler beg wellington',
#  'boiler ber wellington',
#  'boiler bea wellington',
#  'boiler ef wellington',
#  'boiler nef wellington',
#  'boiler bee wellington',
#  'boiler bif wellington',
#  'boiler bep wellington',
#  'boiler lef wellington',
#  'boiler baf wellington',
#  'boiler bsf wellington',
#  'boiler def wellington',
#  'boiler bev wellington',
#  'boiler tef wellington',
#  'boiler befc wellington',
#  'boiler bei wellington',
#  'boiler bff wellington',
#  'boiler eef wellington',
#  'boiler boef wellington',
#  'boiler beef wellington',
#  'boiler bf wellington',
#  'boiler bec wellington',
#  'boiler bew wellington',
#  'boiler beaf wellington',
#  'boiler beff wellington',
#  'boiler beh wellington',
#  'boiler ben wellington',
#  'boiler bey wellington',
#  'boiler bek wellington',
#  'boiler bef wellington',
#  'broiled bof wellington',
#  'broiled bnf wellington',
#  'broiled bet wellington',
#  'broiled bel wellington',
#  'broiled bed wellington',
#  'broiled ref wellington',
#  'broiled beg wellington',
#  'broiled ber wellington',
#  'broiled bea wellington',
#  'broiled ef wellington',
#  'broiled nef wellington',
#  'broiled bee wellington',
#  'broiled bif wellington',
#  'broiled bep wellington',
#  'broiled lef wellington',
#  'broiled baf wellington',
#  'broiled bsf wellington',
#  'broiled def wellington',
#  'broiled bev wellington',
#  'broiled tef wellington',
#  'broiled befc wellington',
#  'broiled bei wellington',
#  'broiled bff wellington',
#  'broiled eef wellington',
#  'broiled boef wellington',
#  'broiled beef wellington',
#  'broiled bf wellington',
#  'broiled bec wellington',
#  'broiled bew wellington',
#  'broiled beaf wellington',
#  'broiled beff wellington',
#  'broiled beh wellington',
#  'broiled ben wellington',
#  'broiled bey wellington',
#  'broiled bek wellington',
#  'broiled bef wellington',
#  'loiled bof wellington',
#  'loiled bnf wellington',
#  'loiled bet wellington',
#  'loiled bel wellington',
#  'loiled bed wellington',
#  'loiled ref wellington',
#  'loiled beg wellington',
#  'loiled ber wellington',
#  'loiled bea wellington',
#  'loiled ef wellington',
#  'loiled nef wellington',
#  'loiled bee wellington',
#  'loiled bif wellington',
#  'loiled bep wellington',
#  'loiled lef wellington',
#  'loiled baf wellington',
#  'loiled bsf wellington',
#  'loiled def wellington',
#  'loiled bev wellington',
#  'loiled tef wellington',
#  'loiled befc wellington',
#  'loiled bei wellington',
#  'loiled bff wellington',
#  'loiled eef wellington',
#  'loiled boef wellington',
#  'loiled beef wellington',
#  'loiled bf wellington',
#  'loiled bec wellington',
#  'loiled bew wellington',
#  'loiled beaf wellington',
#  'loiled beff wellington',
#  'loiled beh wellington',
#  'loiled ben wellington',
#  'loiled bey wellington',
#  'loiled bek wellington',
#  'loiled bef wellington',
#  'bowled bof wellington',
#  'bowled bnf wellington',
#  'bowled bet wellington',
#  'bowled bel wellington',
#  'bowled bed wellington',
#  'bowled ref wellington',
#  'bowled beg wellington',
#  'bowled ber wellington',
#  'bowled bea wellington',
#  'bowled ef wellington',
#  'bowled nef wellington',
#  'bowled bee wellington',
#  'bowled bif wellington',
#  'bowled bep wellington',
#  'bowled lef wellington',
#  'bowled baf wellington',
#  'bowled bsf wellington',
#  'bowled def wellington',
#  'bowled bev wellington',
#  'bowled tef wellington',
#  'bowled befc wellington',
#  'bowled bei wellington',
#  'bowled bff wellington',
#  'bowled eef wellington',
#  'bowled boef wellington',
#  'bowled beef wellington',
#  'bowled bf wellington',
#  'bowled bec wellington',
#  'bowled bew wellington',
#  'bowled beaf wellington',
#  'bowled beff wellington',
#  'bowled beh wellington',
#  'bowled ben wellington',
#  'bowled bey wellington',
#  'bowled bek wellington',
#  'bowled bef wellington',
#  'oiled bof wellington',
#  'oiled bnf wellington',
#  'oiled bet wellington',
#  'oiled bel wellington',
#  'oiled bed wellington',
#  'oiled ref wellington',
#  'oiled beg wellington',
#  'oiled ber wellington',
#  'oiled bea wellington',
#  'oiled ef wellington',
#  'oiled nef wellington',
#  'oiled bee wellington',
#  'oiled bif wellington',
#  'oiled bep wellington',
#  'oiled lef wellington',
#  'oiled baf wellington',
#  'oiled bsf wellington',
#  'oiled def wellington',
#  'oiled bev wellington',
#  'oiled tef wellington',
#  'oiled befc wellington',
#  'oiled bei wellington',
#  'oiled bff wellington',
#  'oiled eef wellington',
#  'oiled boef wellington',
#  'oiled beef wellington',
#  'oiled bf wellington',
#  'oiled bec wellington',
#  'oiled bew wellington',
#  'oiled beaf wellington',
#  'oiled beff wellington',
#  'oiled beh wellington',
#  'oiled ben wellington',
#  'oiled bey wellington',
#  'oiled bek wellington',
#  'oiled bef wellington',
#  'boyled bof wellington',
#  'boyled bnf wellington',
#  'boyled bet wellington',
#  'boyled bel wellington',
#  'boyled bed wellington',
#  'boyled ref wellington',
#  'boyled beg wellington',
#  'boyled ber wellington',
#  'boyled bea wellington',
#  'boyled ef wellington',
#  'boyled nef wellington',
#  'boyled bee wellington',
#  'boyled bif wellington',
#  'boyled bep wellington',
#  'boyled lef wellington',
#  'boyled baf wellington',
#  'boyled bsf wellington',
#  'boyled def wellington',
#  'boyled bev wellington',
#  'boyled tef wellington',
#  'boyled befc wellington',
#  'boyled bei wellington',
#  'boyled bff wellington',
#  'boyled eef wellington',
#  'boyled boef wellington',
#  'boyled beef wellington',
#  'boyled bf wellington',
#  'boyled bec wellington',
#  'boyled bew wellington',
#  'boyled beaf wellington',
#  'boyled beff wellington',
#  'boyled beh wellington',
#  'boyled ben wellington',
#  'boyled bey wellington',
#  'boyled bek wellington',
#  'boyled bef wellington',
#  'toiled bof wellington',
#  'toiled bnf wellington',
#  'toiled bet wellington',
#  'toiled bel wellington',
#  'toiled bed wellington',
#  'toiled ref wellington',
#  'toiled beg wellington',
#  'toiled ber wellington',
#  'toiled bea wellington',
#  'toiled ef wellington',
#  'toiled nef wellington',
#  'toiled bee wellington',
#  'toiled bif wellington',
#  'toiled bep wellington',
#  'toiled lef wellington',
#  'toiled baf wellington',
#  'toiled bsf wellington',
#  'toiled def wellington',
#  'toiled bev wellington',
#  'toiled tef wellington',
#  'toiled befc wellington',
#  'toiled bei wellington',
#  'toiled bff wellington',
#  'toiled eef wellington',
#  'toiled boef wellington',
#  'toiled beef wellington',
#  'toiled bf wellington',
#  'toiled bec wellington',
#  'toiled bew wellington',
#  'toiled beaf wellington',
#  'toiled beff wellington',
#  'toiled beh wellington',
#  'toiled ben wellington',
#  'toiled bey wellington',
#  'toiled bek wellington',
#  'toiled bef wellington',
#  'foiled bof wellington',
#  'foiled bnf wellington',
#  'foiled bet wellington',
#  'foiled bel wellington',
#  'foiled bed wellington',
#  'foiled ref wellington',
#  'foiled beg wellington',
#  'foiled ber wellington',
#  'foiled bea wellington',
#  'foiled ef wellington',
#  'foiled nef wellington',
#  'foiled bee wellington',
#  'foiled bif wellington',
#  'foiled bep wellington',
#  'foiled lef wellington',
#  'foiled baf wellington',
#  'foiled bsf wellington',
#  'foiled def wellington',
#  'foiled bev wellington',
#  'foiled tef wellington',
#  'foiled befc wellington',
#  'foiled bei wellington',
#  'foiled bff wellington',
#  'foiled eef wellington',
#  'foiled boef wellington',
#  'foiled beef wellington',
#  'foiled bf wellington',
#  'foiled bec wellington',
#  'foiled bew wellington',
#  'foiled beaf wellington',
#  'foiled beff wellington',
#  'foiled beh wellington',
#  'foiled ben wellington',
#  'foiled bey wellington',
#  'foiled bek wellington',
#  'foiled bef wellington',
#  'bouled bof wellington',
#  'bouled bnf wellington',
#  'bouled bet wellington',
#  'bouled bel wellington',
#  'bouled bed wellington',
#  'bouled ref wellington',
#  'bouled beg wellington',
#  'bouled ber wellington',
#  'bouled bea wellington',
#  'bouled ef wellington',
#  'bouled nef wellington',
#  'bouled bee wellington',
#  'bouled bif wellington',
#  'bouled bep wellington',
#  'bouled lef wellington',
#  'bouled baf wellington',
#  'bouled bsf wellington',
#  'bouled def wellington',
#  'bouled bev wellington',
#  'bouled tef wellington',
#  'bouled befc wellington',
#  'bouled bei wellington',
#  'bouled bff wellington',
#  'bouled eef wellington',
#  'bouled boef wellington',
#  'bouled beef wellington',
#  'bouled bf wellington',
#  'bouled bec wellington',
#  'bouled bew wellington',
#  'bouled beaf wellington',
#  'bouled beff wellington',
#  'bouled beh wellington',
#  'bouled ben wellington',
#  'bouled bey wellington',
#  'bouled bek wellington',
#  'bouled bef wellington',
#  'boile bof wellington',
#  'boile bnf wellington',
#  'boile bet wellington',
#  'boile bel wellington',
#  'boile bed wellington',
#  'boile ref wellington',
#  'boile beg wellington',
#  'boile ber wellington',
#  'boile bea wellington',
#  'boile ef wellington',
#  'boile nef wellington',
#  'boile bee wellington',
#  'boile bif wellington',
#  'boile bep wellington',
#  'boile lef wellington',
#  'boile baf wellington',
#  'boile bsf wellington',
#  'boile def wellington',
#  'boile bev wellington',
#  'boile tef wellington',
#  'boile befc wellington',
#  'boile bei wellington',
#  'boile bff wellington',
#  'boile eef wellington',
#  'boile boef wellington',
#  'boile beef wellington',
#  'boile bf wellington',
#  'boile bec wellington',
#  'boile bew wellington',
#  'boile beaf wellington',
#  'boile beff wellington',
#  'boile beh wellington',
#  'boile ben wellington',
#  'boile bey wellington',
#  'boile bek wellington',
#  'boile bef wellington',
#  'bolied bof wellington',
#  'bolied bnf wellington',
#  'bolied bet wellington',
#  'bolied bel wellington',
#  'bolied bed wellington',
#  'bolied ref wellington',
#  'bolied beg wellington',
#  'bolied ber wellington',
#  'bolied bea wellington',
#  'bolied ef wellington',
#  'bolied nef wellington',
#  'bolied bee wellington',
#  'bolied bif wellington',
#  'bolied bep wellington',
#  'bolied lef wellington',
#  'bolied baf wellington',
#  'bolied bsf wellington',
#  'bolied def wellington',
#  'bolied bev wellington',
#  'bolied tef wellington',
#  'bolied befc wellington',
#  'bolied bei wellington',
#  'bolied bff wellington',
#  'bolied eef wellington',
#  'bolied boef wellington',
#  'bolied beef wellington',
#  'bolied bf wellington',
#  'bolied bec wellington',
#  'bolied bew wellington',
#  'bolied beaf wellington',
#  'bolied beff wellington',
#  'bolied beh wellington',
#  'bolied ben wellington',
#  'bolied bey wellington',
#  'bolied bek wellington',
#  'bolied bef wellington',
#  'coiled bof wellington',
#  'coiled bnf wellington',
#  'coiled bet wellington',
#  'coiled bel wellington',
#  'coiled bed wellington',
#  'coiled ref wellington',
#  'coiled beg wellington',
#  'coiled ber wellington',
#  'coiled bea wellington',
#  'coiled ef wellington',
#  'coiled nef wellington',
#  'coiled bee wellington',
#  'coiled bif wellington',
#  'coiled bep wellington',
#  'coiled lef wellington',
#  'coiled baf wellington',
#  'coiled bsf wellington',
#  'coiled def wellington',
#  'coiled bev wellington',
#  'coiled tef wellington',
#  'coiled befc wellington',
#  'coiled bei wellington',
#  'coiled bff wellington',
#  'coiled eef wellington',
#  'coiled boef wellington',
#  'coiled beef wellington',
#  'coiled bf wellington',
#  'coiled bec wellington',
#  'coiled bew wellington',
#  'coiled beaf wellington',
#  'coiled beff wellington',
#  'coiled beh wellington',
#  'coiled ben wellington',
#  'coiled bey wellington',
#  'coiled bek wellington',
#  'coiled bef wellington',
#  'boiles bof wellington',
#  'boiles bnf wellington',
#  'boiles bet wellington',
#  'boiles bel wellington',
#  'boiles bed wellington',
#  'boiles ref wellington',
#  'boiles beg wellington',
#  'boiles ber wellington',
#  'boiles bea wellington',
#  'boiles ef wellington',
#  'boiles nef wellington',
#  'boiles bee wellington',
#  'boiles bif wellington',
#  'boiles bep wellington',
#  'boiles lef wellington',
#  'boiles baf wellington',
#  'boiles bsf wellington',
#  'boiles def wellington',
#  'boiles bev wellington',
#  'boiles tef wellington',
#  'boiles befc wellington',
#  'boiles bei wellington',
#  'boiles bff wellington',
#  'boiles eef wellington',
#  'boiles boef wellington',
#  'boiles beef wellington',
#  'boiles bf wellington',
#  'boiles bec wellington',
#  'boiles bew wellington',
#  'boiles beaf wellington',
#  'boiles beff wellington',
#  'boiles beh wellington',
#  'boiles ben wellington',
#  'boiles bey wellington',
#  'boiles bek wellington',
#  'boiles bef wellington',
#  'boild bof wellington',
#  'boild bnf wellington',
#  'boild bet wellington',
#  'boild bel wellington',
#  'boild bed wellington',
#  'boild ref wellington',
#  'boild beg wellington',
#  'boild ber wellington',
#  'boild bea wellington',
#  'boild ef wellington',
#  'boild nef wellington',
#  'boild bee wellington',
#  'boild bif wellington',
#  'boild bep wellington',
#  'boild lef wellington',
#  'boild baf wellington',
#  'boild bsf wellington',
#  'boild def wellington',
#  'boild bev wellington',
#  'boild tef wellington',
#  'boild befc wellington',
#  'boild bei wellington',
#  'boild bff wellington',
#  'boild eef wellington',
#  'boild boef wellington',
#  'boild beef wellington',
#  'boild bf wellington',
#  'boild bec wellington',
#  'boild bew wellington',
#  'boild beaf wellington',
#  'boild beff wellington',
#  'boild beh wellington',
#  'boild ben wellington',
#  'boild bey wellington',
#  'boild bek wellington',
#  'boild bef wellington',
#  'soiled bof wellington',
#  'soiled bnf wellington',
#  'soiled bet wellington',
#  'soiled bel wellington',
#  'soiled bed wellington',
#  'soiled ref wellington',
#  'soiled beg wellington',
#  'soiled ber wellington',
#  'soiled bea wellington',
#  'soiled ef wellington',
#  'soiled nef wellington',
#  'soiled bee wellington',
#  'soiled bif wellington',
#  'soiled bep wellington',
#  'soiled lef wellington',
#  'soiled baf wellington',
#  'soiled bsf wellington',
#  'soiled def wellington',
#  'soiled bev wellington',
#  'soiled tef wellington',
#  'soiled befc wellington',
#  'soiled bei wellington',
#  'soiled bff wellington',
#  'soiled eef wellington',
#  'soiled boef wellington',
#  'soiled beef wellington',
#  'soiled bf wellington',
#  'soiled bec wellington',
#  'soiled bew wellington',
#  'soiled beaf wellington',
#  'soiled beff wellington',
#  'soiled beh wellington',
#  'soiled ben wellington',
#  'soiled bey wellington',
#  'soiled bek wellington',
#  'soiled bef wellington',
#  'boilet bof wellington',
#  'boilet bnf wellington',
#  'boilet bet wellington',
#  'boilet bel wellington',
#  'boilet bed wellington',
#  'boilet ref wellington',
#  'boilet beg wellington',
#  'boilet ber wellington',
#  'boilet bea wellington',
#  'boilet ef wellington',
#  'boilet nef wellington',
#  'boilet bee wellington',
#  'boilet bif wellington',
#  'boilet bep wellington',
#  'boilet lef wellington',
#  'boilet baf wellington',
#  'boilet bsf wellington',
#  'boilet def wellington',
#  'boilet bev wellington',
#  'boilet tef wellington',
#  'boilet befc wellington',
#  'boilet bei wellington',
#  'boilet bff wellington',
#  'boilet eef wellington',
#  'boilet boef wellington',
#  'boilet beef wellington',
#  'boilet bf wellington',
#  'boilet bec wellington',
#  'boilet bew wellington',
#  'boilet beaf wellington',
#  'boilet beff wellington',
#  'boilet beh wellington',
#  'boilet ben wellington',
#  'boilet bey wellington',
#  'boilet bek wellington',
#  'boilet bef wellington',
#  'boled bof wellington',
#  'boled bnf wellington',
#  'boled bet wellington',
#  'boled bel wellington',
#  'boled bed wellington',
#  'boled ref wellington',
#  'boled beg wellington',
#  'boled ber wellington',
#  'boled bea wellington',
#  'boled ef wellington',
#  'boled nef wellington',
#  'boled bee wellington',
#  'boled bif wellington',
#  'boled bep wellington',
#  'boled lef wellington',
#  'boled baf wellington',
#  'boled bsf wellington',
#  'boled def wellington',
#  'boled bev wellington',
#  'boled tef wellington',
#  'boled befc wellington',
#  'boled bei wellington',
#  'boled bff wellington',
#  'boled eef wellington',
#  'boled boef wellington',
#  'boled beef wellington',
#  'boled bf wellington',
#  'boled bec wellington',
#  'boled bew wellington',
#  'boled beaf wellington',
#  'boled beff wellington',
#  'boled beh wellington',
#  'boled ben wellington',
#  'boled bey wellington',
#  'boled bek wellington',
#  'boled bef wellington',
#  'boiled bof wellington',
#  'boiled bnf wellington',
#  'boiled bet wellington',
#  'boiled bel wellington',
#  'boiled bed wellington',
#  'boiled ref wellington',
#  'boiled beg wellington',
#  'boiled ber wellington',
#  'boiled bea wellington',
#  'boiled ef wellington',
#  'boiled nef wellington',
#  'boiled bee wellington',
#  'boiled bif wellington',
#  'boiled bep wellington',
#  'boiled lef wellington',
#  'boiled baf wellington',
#  'boiled bsf wellington',
#  'boiled def wellington',
#  'boiled bev wellington',
#  'boiled tef wellington',
#  'boiled befc wellington',
#  'boiled bei wellington',
#  'boiled bff wellington',
#  'boiled eef wellington',
#  'boiled boef wellington',
#  'boiled beef wellington',
#  'boiled bf wellington',
#  'boiled bec wellington',
#  'boiled bew wellington',
#  'boiled beaf wellington',
#  'boiled beff wellington',
#  'boiled beh wellington',
#  'boiled ben wellington',
#  'boiled bey wellington',
#  'boiled bek wellington',
#  'boiled bef wellington',
#  'boiler bof wellinton',
#  'boiler bnf wellinton',
#  'boiler bet wellinton',
#  'boiler bel wellinton',
#  'boiler bed wellinton',
#  'boiler ref wellinton',
#  'boiler beg wellinton',
#  'boiler ber wellinton',
#  'boiler bea wellinton',
#  'boiler ef wellinton',
#  'boiler nef wellinton',
#  'boiler bee wellinton',
#  'boiler bif wellinton',
#  'boiler bep wellinton',
#  'boiler lef wellinton',
#  'boiler baf wellinton',
#  'boiler bsf wellinton',
#  'boiler def wellinton',
#  'boiler bev wellinton',
#  'boiler tef wellinton',
#  'boiler befc wellinton',
#  'boiler bei wellinton',
#  'boiler bff wellinton',
#  'boiler eef wellinton',
#  'boiler boef wellinton',
#  'boiler beef wellinton',
#  'boiler bf wellinton',
#  'boiler bec wellinton',
#  'boiler bew wellinton',
#  'boiler beaf wellinton',
#  'boiler beff wellinton',
#  'boiler beh wellinton',
#  'boiler ben wellinton',
#  'boiler bey wellinton',
#  'boiler bek wellinton',
#  'boiler bef wellinton',
#  'broiled bof wellinton',
#  'broiled bnf wellinton',
#  'broiled bet wellinton',
#  'broiled bel wellinton',
#  'broiled bed wellinton',
#  'broiled ref wellinton',
#  'broiled beg wellinton',
#  'broiled ber wellinton',
#  'broiled bea wellinton',
#  'broiled ef wellinton',
#  'broiled nef wellinton',
#  'broiled bee wellinton',
#  'broiled bif wellinton',
#  'broiled bep wellinton',
#  'broiled lef wellinton',
#  'broiled baf wellinton',
#  'broiled bsf wellinton',
#  'broiled def wellinton',
#  'broiled bev wellinton',
#  'broiled tef wellinton',
#  'broiled befc wellinton',
#  'broiled bei wellinton',
#  'broiled bff wellinton',
#  'broiled eef wellinton',
#  'broiled boef wellinton',
#  'broiled beef wellinton',
#  'broiled bf wellinton',
#  'broiled bec wellinton',
#  'broiled bew wellinton',
#  'broiled beaf wellinton',
#  'broiled beff wellinton',
#  'broiled beh wellinton',
#  'broiled ben wellinton',
#  'broiled bey wellinton',
#  'broiled bek wellinton',
#  'broiled bef wellinton',
#  'loiled bof wellinton',
#  'loiled bnf wellinton',
#  'loiled bet wellinton',
#  'loiled bel wellinton',
#  'loiled bed wellinton',
#  'loiled ref wellinton',
#  'loiled beg wellinton',
#  'loiled ber wellinton',
#  'loiled bea wellinton',
#  'loiled ef wellinton',
#  'loiled nef wellinton',
#  'loiled bee wellinton',
#  'loiled bif wellinton',
#  'loiled bep wellinton',
#  'loiled lef wellinton',
#  'loiled baf wellinton',
#  'loiled bsf wellinton',
#  'loiled def wellinton',
#  'loiled bev wellinton',
#  'loiled tef wellinton',
#  'loiled befc wellinton',
#  'loiled bei wellinton',
#  'loiled bff wellinton',
#  'loiled eef wellinton',
#  'loiled boef wellinton',
#  'loiled beef wellinton',
#  'loiled bf wellinton',
#  'loiled bec wellinton',
#  'loiled bew wellinton',
#  'loiled beaf wellinton',
#  'loiled beff wellinton',
#  'loiled beh wellinton',
#  'loiled ben wellinton',
#  'loiled bey wellinton',
#  'loiled bek wellinton',
#  'loiled bef wellinton',
#  'bowled bof wellinton',
#  'bowled bnf wellinton',
#  'bowled bet wellinton',
#  'bowled bel wellinton',
#  'bowled bed wellinton',
#  'bowled ref wellinton',
#  'bowled beg wellinton',
#  'bowled ber wellinton',
#  'bowled bea wellinton',
#  'bowled ef wellinton',
#  'bowled nef wellinton',
#  'bowled bee wellinton',
#  'bowled bif wellinton',
#  'bowled bep wellinton',
#  'bowled lef wellinton',
#  'bowled baf wellinton',
#  'bowled bsf wellinton',
#  'bowled def wellinton',
#  'bowled bev wellinton',
#  'bowled tef wellinton',
#  'bowled befc wellinton',
#  'bowled bei wellinton',
#  'bowled bff wellinton',
#  'bowled eef wellinton',
#  'bowled boef wellinton',
#  'bowled beef wellinton',
#  'bowled bf wellinton',
#  'bowled bec wellinton',
#  'bowled bew wellinton',
#  'bowled beaf wellinton',
#  'bowled beff wellinton',
#  'bowled beh wellinton',
#  'bowled ben wellinton',
#  'bowled bey wellinton',
#  'bowled bek wellinton',
#  'bowled bef wellinton',
#  'oiled bof wellinton',
#  'oiled bnf wellinton',
#  'oiled bet wellinton',
#  'oiled bel wellinton',
#  'oiled bed wellinton',
#  'oiled ref wellinton',
#  'oiled beg wellinton',
#  'oiled ber wellinton',
#  'oiled bea wellinton',
#  'oiled ef wellinton',
#  'oiled nef wellinton',
#  'oiled bee wellinton',
#  'oiled bif wellinton',
#  'oiled bep wellinton',
#  'oiled lef wellinton',
#  'oiled baf wellinton',
#  'oiled bsf wellinton',
#  'oiled def wellinton',
#  'oiled bev wellinton',
#  'oiled tef wellinton',
#  'oiled befc wellinton',
#  'oiled bei wellinton',
#  'oiled bff wellinton',
#  'oiled eef wellinton',
#  'oiled boef wellinton',
#  'oiled beef wellinton',
#  'oiled bf wellinton',
#  'oiled bec wellinton',
#  'oiled bew wellinton',
#  'oiled beaf wellinton',
#  'oiled beff wellinton',
#  'oiled beh wellinton',
#  'oiled ben wellinton',
#  'oiled bey wellinton',
#  'oiled bek wellinton',
#  'oiled bef wellinton',
#  'boyled bof wellinton',
#  'boyled bnf wellinton',
#  'boyled bet wellinton',
#  'boyled bel wellinton',
#  'boyled bed wellinton',
#  'boyled ref wellinton',
#  'boyled beg wellinton',
#  'boyled ber wellinton',
#  'boyled bea wellinton',
#  'boyled ef wellinton',
#  'boyled nef wellinton',
#  'boyled bee wellinton',
#  'boyled bif wellinton',
#  'boyled bep wellinton',
#  'boyled lef wellinton',
#  'boyled baf wellinton',
#  'boyled bsf wellinton',
#  'boyled def wellinton',
#  'boyled bev wellinton',
#  'boyled tef wellinton',
#  'boyled befc wellinton',
#  'boyled bei wellinton',
#  'boyled bff wellinton',
#  'boyled eef wellinton',
#  'boyled boef wellinton',
#  'boyled beef wellinton',
#  'boyled bf wellinton',
#  'boyled bec wellinton',
#  'boyled bew wellinton',
#  'boyled beaf wellinton',
#  'boyled beff wellinton',
#  'boyled beh wellinton',
#  'boyled ben wellinton',
#  'boyled bey wellinton',
#  'boyled bek wellinton',
#  'boyled bef wellinton',
#  'toiled bof wellinton',
#  'toiled bnf wellinton',
#  'toiled bet wellinton',
#  'toiled bel wellinton',
#  'toiled bed wellinton',
#  'toiled ref wellinton',
#  'toiled beg wellinton',
#  'toiled ber wellinton',
#  'toiled bea wellinton',
#  'toiled ef wellinton',
#  'toiled nef wellinton',
#  'toiled bee wellinton',
#  'toiled bif wellinton',
#  'toiled bep wellinton',
#  'toiled lef wellinton',
#  'toiled baf wellinton',
#  'toiled bsf wellinton',
#  'toiled def wellinton',
#  'toiled bev wellinton',
#  'toiled tef wellinton',
#  'toiled befc wellinton',
#  'toiled bei wellinton',
#  'toiled bff wellinton',
#  'toiled eef wellinton',
#  'toiled boef wellinton',
#  'toiled beef wellinton',
#  'toiled bf wellinton',
#  'toiled bec wellinton',
#  'toiled bew wellinton',
#  'toiled beaf wellinton',
#  'toiled beff wellinton',
#  'toiled beh wellinton',
#  'toiled ben wellinton',
#  'toiled bey wellinton',
#  'toiled bek wellinton',
#  'toiled bef wellinton',
#  'foiled bof wellinton',
#  'foiled bnf wellinton',
#  'foiled bet wellinton',
#  'foiled bel wellinton',
#  'foiled bed wellinton',
#  'foiled ref wellinton',
#  'foiled beg wellinton',
#  'foiled ber wellinton',
#  'foiled bea wellinton',
#  'foiled ef wellinton',
#  'foiled nef wellinton',
#  'foiled bee wellinton',
#  'foiled bif wellinton',
#  'foiled bep wellinton',
#  'foiled lef wellinton',
#  'foiled baf wellinton',
#  'foiled bsf wellinton',
#  'foiled def wellinton',
#  'foiled bev wellinton',
#  'foiled tef wellinton',
#  'foiled befc wellinton',
#  'foiled bei wellinton',
#  'foiled bff wellinton',
#  'foiled eef wellinton',
#  'foiled boef wellinton',
#  'foiled beef wellinton',
#  'foiled bf wellinton',
#  'foiled bec wellinton',
#  'foiled bew wellinton',
#  'foiled beaf wellinton',
#  'foiled beff wellinton',
#  'foiled beh wellinton',
#  'foiled ben wellinton',
#  'foiled bey wellinton',
#  'foiled bek wellinton',
#  'foiled bef wellinton',
#  'bouled bof wellinton',
#  'bouled bnf wellinton',
#  'bouled bet wellinton',
#  'bouled bel wellinton',
#  'bouled bed wellinton',
#  'bouled ref wellinton',
#  'bouled beg wellinton',
#  'bouled ber wellinton',
#  'bouled bea wellinton',
#  'bouled ef wellinton',
#  'bouled nef wellinton',
#  'bouled bee wellinton',
#  'bouled bif wellinton',
#  'bouled bep wellinton',
#  'bouled lef wellinton',
#  'bouled baf wellinton',
#  'bouled bsf wellinton',
#  'bouled def wellinton',
#  'bouled bev wellinton',
#  'bouled tef wellinton',
#  'bouled befc wellinton',
#  'bouled bei wellinton',
#  'bouled bff wellinton',
#  'bouled eef wellinton',
#  'bouled boef wellinton',
#  'bouled beef wellinton',
#  'bouled bf wellinton',
#  'bouled bec wellinton',
#  'bouled bew wellinton',
#  'bouled beaf wellinton',
#  'bouled beff wellinton',
#  'bouled beh wellinton',
#  'bouled ben wellinton',
#  'bouled bey wellinton',
#  'bouled bek wellinton',
#  'bouled bef wellinton',
#  'boile bof wellinton',
#  'boile bnf wellinton',
#  'boile bet wellinton',
#  'boile bel wellinton',
#  'boile bed wellinton',
#  'boile ref wellinton',
#  'boile beg wellinton',
#  'boile ber wellinton',
#  'boile bea wellinton',
#  'boile ef wellinton',
#  'boile nef wellinton',
#  'boile bee wellinton',
#  'boile bif wellinton',
#  'boile bep wellinton',
#  'boile lef wellinton',
#  'boile baf wellinton',
#  'boile bsf wellinton',
#  'boile def wellinton',
#  'boile bev wellinton',
#  'boile tef wellinton',
#  'boile befc wellinton',
#  'boile bei wellinton',
#  'boile bff wellinton',
#  'boile eef wellinton',
#  'boile boef wellinton',
#  'boile beef wellinton',
#  'boile bf wellinton',
#  'boile bec wellinton',
#  ...]
